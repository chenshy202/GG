# %% [markdown]
# ### Real data

# %%
import numpy as np
import scipy.io
import torch
from torch_geometric.data import Data
from pathlib import Path
from torch_geometric.datasets import KarateClub, WikipediaNetwork, Planetoid
from prettytable import PrettyTable
from itertools import chain
import networkx as nx
import random
import torch.nn as nn
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import accuracy_score
import random
from models import GEE, GNN
from time import time
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

def _dedup_edges(edge: torch.Tensor) -> torch.Tensor:
    """
    Converts a directed edge list to an undirected one and removes duplicate edges.
    This is a helper function to ensure graph consistency.

    Args:
        edge (torch.Tensor): A [2, num_edges] tensor representing the edge index.

    Returns:
        torch.Tensor: A processed edge index tensor with no duplicates or self-loops.
    """
    row = torch.minimum(edge[0], edge[1])
    col = torch.maximum(edge[0], edge[1])
    edge_undirected = torch.stack([row, col], dim=0)   

    return torch.unique(edge_undirected, dim=1)

def load_real_data(name: str, root: str = "../datasets"):
    """
    Loads real-world graph datasets from various sources.
    It supports three loading mechanisms:
      1. PyTorch Geometric's online datasets (e.g., "Cora").
      2. Local .mat files (e.g., "your_dataset.mat").
      3. A directory of .npy files for adj, features, and labels.

    Args:
        name (str): The name of the dataset.
        root (str, optional): The root directory for datasets. Defaults to "./datasets".

    Returns:
        torch_geometric.data.Data: A PyG Data object containing graph info.
    """
    # --- 1. Load from PyG's online library ---
    online_map = {
        "KarateClub":        lambda: KarateClub(),
        "Chameleon":         lambda: WikipediaNetwork(root, name="Chameleon"),
        "Cora":              lambda: Planetoid(root, name="Cora"),
        "Citeseer":          lambda: Planetoid(root, name="Citeseer"),
    }
    if name in online_map:
        ds = online_map[name]()       
        data  = ds[0]
        data.edge_index = _dedup_edges(data.edge_index)  
        data.k = ds.num_classes   
        return data

    # --- 2 & 3. Load from local files ---
    root = Path(root)
    mat_file = root / f"{name}.mat"
    npy_dir  = root / name

    if mat_file.exists():                                  # -------- mat --------
        mat  = scipy.io.loadmat(mat_file)
        edge = torch.tensor(mat["Edge"][:, :2].T, dtype=torch.long) - 1
        edge = _dedup_edges(edge)
        if edge.max() == 1:
            edge -= 1

        lbl_key = "Label" if "Label" in mat else "Y"
        y = torch.tensor(mat[lbl_key].ravel(), dtype=torch.long)
        data = Data(x=None, edge_index=edge, y=y)

    elif npy_dir.is_dir():                                 # -------- npy --------
        adj   = np.load(npy_dir / f"{name}_adj.npy")
        feat  = np.load(npy_dir / f"{name}_feat.npy").astype(np.float32)
        label = np.load(npy_dir / f"{name}_label.npy")

        row, col = np.where(adj > 0)
        edge = torch.tensor(np.vstack([row, col]), dtype=torch.long)
        if np.allclose(adj, adj.T):
            edge = _dedup_edges(edge)
        # if edge.min() == 1:
        #     edge -= 1

        data = Data(x=torch.tensor(feat), edge_index=edge,
                    y=torch.tensor(label, dtype=torch.long))
    else:
        raise FileNotFoundError(f"Dataset '{name}' not found in {root}.")

    data.k = len(torch.unique(data.y))
    data.num_nodes = data.y.shape[0]

    if min(data.y) == 1 and max(data.y) == data.k:
        data.y  -= 1
    
    return data

def stratified_split(labels, train_ratio=0.18, val_ratio=0.02, test_ratio=0.80, n_repeats=100, seed=0):
    """Creates repeated stratified train/validation/test splits for labels.

    Args:
        labels: A 1D array or tensor of node labels.
        train_ratio (float): The approximate proportion for the training set.
        val_ratio (float): The approximate proportion for the validation set.
        n_repeats (int): The number of distinct splits to generate.
        seed (int): The random seed for reproducibility.

    Returns:
        list: A list of dictionaries, each holding 'train', 'val', 'test' indices.
    """
    y = labels.cpu().numpy() if torch.is_tensor(labels) else labels
    rng = np.random.default_rng(seed)
    num_classes = np.unique(y).size
    all_splits = []
    for repeat in range(n_repeats):
        train_idx, val_idx, test_idx = [], [], []
        for c in np.unique(y):

            idx = np.where(y == c)[0]
            idx = rng.permutation(idx)
            n = len(idx)
            if n == 3:
                train_idx.append(idx[:2])
                val_idx.append(idx[2])
            if n <= 2:
                raise ValueError(f"Not enough samples")
            else:
                n_train = max(2, int(np.round(train_ratio * n)))
                n_val = max(1, int(np.round(val_ratio * n)))
                n_test = n - n_train - n_val

                train_idx.append(idx[:n_train])
                val_idx.append(idx[n_train:n_train+n_val])
                test_idx.append(idx[n_train+n_val:])

        train_idx = np.concatenate(train_idx)
        val_idx = np.concatenate(val_idx)
        test_idx = np.concatenate(test_idx)
        all_splits.append({
            'train': train_idx,
            'val': val_idx,
            'test': test_idx,
        })
    return all_splits

def write(file_path, content, dataset):
    """
    Appends experiment results for a given run to a tab-separated file.

    Args:
        file_path (str): The path to the output file.
        content (dict): A dictionary mapping method names to their results.
        dataset (str): The dataset we used.
    """
    with open(file_path, "a") as f:
        for method, arr in content.items():
            arr = np.asarray(arr, dtype=float)
            # flat = arr.flatten()
            ari_str = ",".join(f"{x}" for x in arr)
            line = f"{dataset}\t{method}\t{ari_str}\n"
            f.write(line)

def lda_eval(emb, idx, y_true, solver="lsqr", shrinkage="auto"):
    """
    Evaluates node embeddings using a Linear Discriminant Analysis (LDA) classifier.

    Args:
        emb: A 2D array or tensor of node embeddings.
        idx (dict): A dictionary containing 'train', 'val', and 'test' indices.
        y_true (torch.Tensor): The ground-truth labels for all nodes.

    Returns:
        float: The classification accuracy on the test set.
    """
    if isinstance(emb, torch.Tensor):
        emb = emb.detach().cpu().numpy()

    idx_train_all = np.concatenate([idx["train"], idx["val"]])
    idx_test = idx["test"]

    X_train, y_train = emb[idx_train_all], y_true[idx_train_all]
    X_test,  y_test  = emb[idx_test],      y_true[idx_test]

    lda = LinearDiscriminantAnalysis(solver=solver, shrinkage=shrinkage)
    lda.fit(X_train, y_train)
    y_pred = lda.predict(X_test)
    acc    = accuracy_score(y_test, y_pred)
    return acc

# %%
def run_realdata(data, edge_list, cv_splits, *, gnn_kwargs = None):
    """Orchestrates a comparative experiment of different models on a dataset.

    Args:
        data: The PyTorch Geometric `Data` object for the dataset.
        edge_list (list): The edge list format required by the GEE model.
        cv_splits (list): A list of train/val/test splits, one for each repetition.
        gnn_kwargs (dict, optional): Keyword arguments for the GNN training function.

    Returns:
        tuple: A tuple containing dictionaries for accuracies (`acc_all`),
               execution times (`time_all`), and diagnostic info (`grad_infs`).
    """
    torch.manual_seed(0)
    acc_all = {'GEE':[], 'GNN':[], "GG":[], "GG2":[]}
    time_all = {'GEE':[], 'GNN':[], "GG":[], "GG2":[]}
    loss_all = {}
    grad_all = {}
    stats_acc = {}
    stats_time = {}
    n_reps = len(cv_splits)

    for rep in range(n_reps):
        idx = cv_splits[rep]
        y_true = data.y[idx["test"]]

        # ----------  GEE ----------
        y_train = np.asarray(data.y).copy().reshape(-1,1)
        y_train[idx["val"]] = -1
        y_train[idx["test"]] = -1
        start=time(); Z = GEE.GEE(data.num_nodes, edge_list, y_train); end=time(); t_GEE= end-start
        # y_pred_GEE = torch.argmax(Z, dim=1)[idx["test"]]
        # acc_GEE = accuracy_score(y_true, y_pred_GEE)

        
        # ----------  GNN, GG ----------    
        d_GNN = data.clone()
        d_GG = data.clone()
        d_GG.x = Z
        d_GG2 = data.clone()
        d_GG2.x = Z
        for m in ("train", "val", "test"):
            mask = torch.zeros(d_GNN.num_nodes, dtype=torch.bool)
            mask[idx[m]] = True
            setattr(d_GNN, f"{m}_mask", mask)
            setattr(d_GG, f"{m}_mask", mask)
            setattr(d_GG2, f"{m}_mask", mask)
        
        if rep == 0:
            gnn_kwargs['return_grad'] = True

        start=time(); model_GNN, logits_GNN, grad_inf_GNN = GNN.train(d_GNN, **gnn_kwargs); end=time(); t_GNN= end-start
        y_pred_GNN = logits_GNN.argmax(dim=1)[idx["test"]]
        acc_GNN = accuracy_score(y_true, y_pred_GNN)

        start=time(); model_GG, logits_GG, grad_inf_GG = GNN.train(d_GG, **gnn_kwargs); end=time(); t_GG= end-start
        y_pred_GG = logits_GG.argmax(dim=1)[idx["test"]]
        acc_GG = accuracy_score(y_true, y_pred_GG)

        Z_std  = StandardScaler().fit_transform(Z.detach().cpu().numpy())
        GG_std = StandardScaler().fit_transform(logits_GG.detach().cpu().numpy())

        logits_GG2  = np.concatenate([GG_std, Z_std], axis=1)
        
        acc_GEE = lda_eval(Z,          idx, data.y)
        # acc_GNN = lda_eval(logits_GNN, idx, data.y)
        # acc_GG  = lda_eval(logits_GG,  idx, data.y)
        acc_GG2 = lda_eval(logits_GG2, idx, data.y)

        if gnn_kwargs['return_grad'] == True:
            loss_all['GNN'] = grad_inf_GNN[0]
            loss_all['GG'] = grad_inf_GG[0]
            grad_all['GNN'] = grad_inf_GNN[1]
            grad_all['GG'] = grad_inf_GG[1]
            gnn_kwargs['return_grad'] = False

        acc_list = [acc_GEE, acc_GNN, acc_GG, acc_GG2]
        time_list = [t_GEE, t_GNN, t_GG, t_GG]
        for i, m in enumerate(acc_all):
            acc_all[m].append(acc_list[i])
            time_all[m].append(time_list[i])

            # print(f"  Fold {fold+1}: GEE = {acc_GEE:.4f}, GNN = {acc_GNN:.4f}, GG = {acc_GG:.4f}")

    for m in acc_all:
        arr = np.array(acc_all[m])
        stats_acc[m] = arr.mean(), arr.std(ddof=1)/np.sqrt(100)

        # arr = np.array(time_lists[m])
        # stats_time[m] = arr.mean(), arr.std(ddof=1)/np.sqrt(5)

    print(f"GEE = {stats_acc['GEE'][0]:.4f}±{stats_acc['GEE'][1]:.4f}, \
        GNN = {stats_acc['GNN'][0]:.4f}±{stats_acc['GNN'][1]:.4f},\
            GG = {stats_acc['GG'][0]:.4f}±{stats_acc['GG'][1]:.4f},\
                GG2 = {stats_acc['GG2'][0]:.4f}±{stats_acc['GG2'][1]:.4f}")


    grad_infs = grad_all, loss_all if grad_inf_GNN != None else None
    
    return acc_all, time_all, grad_infs

# %%
# --- 1. Define the list of datasets to be analyzed ---
# Datasets are categorized by their source format (.npy, .mat, or integrated).
data_npy_list = ["ACM","BAT","DBLP","EAT","UAT", "Wiki"]
data_mat_list = ["Gene", "IIP", "lastfm", "polblogs", "TerroristRel"]
data_int_list = ["KarateClub", "Chameleon", "Cora", "Citeseer"]
data_list = data_npy_list +  data_mat_list + data_int_list

# --- 2. Iterate through datasets to collect statistics ---
# We will store statistics in a dictionary for easy table generation.
rows = {
    "num_nodes" : [],
    "num_edges" : [],
    "num_classes": [],
    "feat_dim"  : [],
}

for name in data_list:
    data = load_real_data(name) 
    print(data)          
    rows["num_nodes" ].append(data.y.shape[0])
    rows["num_edges" ].append(data.edge_index.size(1))
    rows["num_classes"].append(data.k)
    rows["feat_dim"  ].append(None if data.x is None else data.x.size(1))

# --- 3. Format and print the statistics using PrettyTable ---
table_long = PrettyTable()
table_long.field_names = ["Info"] + data_list
for info, vals in rows.items():
    table_long.add_row([info] + vals)

print(table_long)
# Out:
# Data(x=[3025, 1870], edge_index=[2, 13128], y=[3025], k=3, num_nodes=3025)
# Data(x=[131, 81], edge_index=[2, 1074], y=[131], k=4, num_nodes=131)
# Data(x=[4057, 334], edge_index=[2, 3528], y=[4057], k=4, num_nodes=4057)
# Data(x=[399, 203], edge_index=[2, 5995], y=[399], k=4, num_nodes=399)
# Data(x=[1190, 239], edge_index=[2, 13599], y=[1190], k=4, num_nodes=1190)
# Data(x=[2405, 4973], edge_index=[2, 16523], y=[2405], k=17, num_nodes=2405)
# Data(edge_index=[2, 1672], y=[1103], k=2, num_nodes=1103)
# Data(edge_index=[2, 630], y=[219], k=3, num_nodes=219)
# Data(edge_index=[2, 27806], y=[7624], k=18, num_nodes=7624)
# Data(edge_index=[2, 16715], y=[1224], k=2, num_nodes=1224)
# Data(edge_index=[2, 8592], y=[881], k=3, num_nodes=881)
# Data(x=[34, 34], edge_index=[2, 78], y=[34], train_mask=[34], k=4)
# Data(x=[2277, 2325], edge_index=[2, 31421], y=[2277], train_mask=[2277, 10], val_mask=[2277, 10], test_mask=[2277, 10], k=5)
# Data(x=[2708, 1433], edge_index=[2, 5278], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], k=7)
# Data(x=[3327, 3703], edge_index=[2, 4552], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327], k=6)
# +-------------+-------+------+------+------+-------+-------+------+------+--------+----------+--------------+------------+-----------+------+----------+
# |     Info    |  ACM  | BAT  | DBLP | EAT  |  UAT  |  Wiki | Gene | IIP  | lastfm | polblogs | TerroristRel | KarateClub | Chameleon | Cora | Citeseer |
# +-------------+-------+------+------+------+-------+-------+------+------+--------+----------+--------------+------------+-----------+------+----------+
# |  num_nodes  |  3025 | 131  | 4057 | 399  |  1190 |  2405 | 1103 | 219  |  7624  |   1224   |     881      |     34     |    2277   | 2708 |   3327   |
# |  num_edges  | 13128 | 1074 | 3528 | 5995 | 13599 | 16523 | 1672 | 630  | 27806  |  16715   |     8592     |     78     |   31421   | 5278 |   4552   |
# | num_classes |   3   |  4   |  4   |  4   |   4   |   17  |  2   |  3   |   18   |    2     |      3       |     4      |     5     |  7   |    6     |
# |   feat_dim  |  1870 |  81  | 334  | 203  |  239  |  4973 | None | None |  None  |   None   |     None     |     34     |    2325   | 1433 |   3703   |
# +-------------+-------+------+------+------+-------+-------+------+------+--------+----------+--------------+------------+-----------+------+----------+

# %%
# =============================================================================
# Main script for evaluating models on real-world graph datasets.
#
# This script systematically evaluates the performance of different models
# (e.g., GEE, GNN, GG) across various datasets by varying the k-fold
# cross-validation setup (k = 2, 5, 10, 20). Multiple replications are run
# for each setting to ensure robust results.
# =============================================================================
torch.manual_seed(901)
random.seed(901)
np.random.seed(901)
n_reps = 100

# G, Y = generate_sbm(n, k, pq, r)
# G.add_edges_from((i, i) for i in range(n))

for num_folds in [20]:
    percent = int(100 / num_folds)
    for dataname in data_list:
         
        data = load_real_data(dataname)
        edge_list = [(int(data.edge_index[0, i]), int(data.edge_index[1, i]), 1) for i in range(data.edge_index.shape[1])]
        initializer = nn.init.xavier_uniform_
        z = initializer(torch.empty(data.num_nodes, data.k))
        data.x = z
        cv_splits = stratified_split(data.y, train_ratio=0.9/num_folds, val_ratio=0.1/num_folds, test_ratio=1/num_folds, n_repeats=n_reps)

        gnn_kwargs = dict(k=data.k, lr=0.001, num_epochs=10000, patience=100, concat= False, return_grad=False)

        acc_all, time_all, grad_infs = run_realdata(data, edge_list, cv_splits, gnn_kwargs=gnn_kwargs)

        write(f"results/real_data/{percent}%/accLe3.txt", acc_all, dataname)
        write(f"results/real_data/{percent}%/timeLe3.txt", time_all, dataname)

        # if grad_infs != None:
        #     grad_all, loss_all = grad_infs
        
            # write(f"results/DC_SBM/{num_folds}fold/grad.txt", grad_all, r)
            # write(f"results/DC_SBM/{num_folds}fold/loss.txt", loss_all, r)
            # write(f"results/DC_SBM/{num_folds}fold/val.txt", val_all, r)
# Out:
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2550 | TrainAcc 0.294 | ValAcc 0.400
# Epoch   10 | Loss 0.9308 | TrainAcc 0.551 | ValAcc 0.267
# Epoch   20 | Loss 0.7402 | TrainAcc 0.728 | ValAcc 0.267
# Epoch   30 | Loss 0.6308 | TrainAcc 0.882 | ValAcc 0.400
# Epoch   40 | Loss 0.5577 | TrainAcc 0.934 | ValAcc 0.267
# Epoch   50 | Loss 0.5122 | TrainAcc 0.978 | ValAcc 0.467
# Epoch   60 | Loss 0.4892 | TrainAcc 0.993 | ValAcc 0.467
# Epoch   70 | Loss 0.4774 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   80 | Loss 0.4715 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   90 | Loss 0.4685 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  100 | Loss 0.4665 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  110 | Loss 0.4654 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  120 | Loss 0.4646 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  130 | Loss 0.4641 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  140 | Loss 0.4638 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.424
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.3433 | TrainAcc 0.250 | ValAcc 0.333
# Epoch   10 | Loss 1.2363 | TrainAcc 0.265 | ValAcc 0.333
# Epoch   20 | Loss 1.1944 | TrainAcc 0.265 | ValAcc 0.333
# Epoch   30 | Loss 1.1442 | TrainAcc 0.265 | ValAcc 0.333
# Epoch   40 | Loss 1.0808 | TrainAcc 0.279 | ValAcc 0.333
# Epoch   50 | Loss 1.0067 | TrainAcc 0.390 | ValAcc 0.400
# Epoch   60 | Loss 0.9347 | TrainAcc 0.529 | ValAcc 0.400
# Epoch   70 | Loss 0.8769 | TrainAcc 0.551 | ValAcc 0.400
# Epoch   80 | Loss 0.8324 | TrainAcc 0.632 | ValAcc 0.400
# Epoch   90 | Loss 0.7959 | TrainAcc 0.721 | ValAcc 0.400
# Epoch  100 | Loss 0.7657 | TrainAcc 0.735 | ValAcc 0.400
# Epoch  110 | Loss 0.7411 | TrainAcc 0.743 | ValAcc 0.400
# Epoch  120 | Loss 0.7214 | TrainAcc 0.757 | ValAcc 0.400
# Epoch  130 | Loss 0.7056 | TrainAcc 0.765 | ValAcc 0.400
# Epoch  140 | Loss 0.6932 | TrainAcc 0.787 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.491
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1621 | TrainAcc 0.368 | ValAcc 0.333
# Epoch   10 | Loss 0.8917 | TrainAcc 0.640 | ValAcc 0.400
# Epoch   20 | Loss 0.7303 | TrainAcc 0.779 | ValAcc 0.333
# Epoch   30 | Loss 0.6397 | TrainAcc 0.860 | ValAcc 0.400
# Epoch   40 | Loss 0.5858 | TrainAcc 0.912 | ValAcc 0.400
# Epoch   50 | Loss 0.5514 | TrainAcc 0.926 | ValAcc 0.467
# Epoch   60 | Loss 0.5291 | TrainAcc 0.949 | ValAcc 0.533
# Epoch   70 | Loss 0.5148 | TrainAcc 0.963 | ValAcc 0.533
# Epoch   80 | Loss 0.5066 | TrainAcc 0.971 | ValAcc 0.533
# Epoch   90 | Loss 0.4997 | TrainAcc 0.993 | ValAcc 0.533
# Epoch  100 | Loss 0.4933 | TrainAcc 0.993 | ValAcc 0.533
# Epoch  110 | Loss 0.4877 | TrainAcc 1.000 | ValAcc 0.533
# Epoch  120 | Loss 0.4841 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  130 | Loss 0.4815 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  140 | Loss 0.4789 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  150 | Loss 0.4780 | TrainAcc 1.000 | ValAcc 0.533
# Epoch  160 | Loss 0.4755 | TrainAcc 1.000 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.392
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2668 | TrainAcc 0.346 | ValAcc 0.333
# Epoch   10 | Loss 1.2534 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   20 | Loss 1.2375 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   30 | Loss 1.2200 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   40 | Loss 1.2007 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   50 | Loss 1.1794 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   60 | Loss 1.1556 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   70 | Loss 1.1292 | TrainAcc 0.419 | ValAcc 0.467
# Epoch   80 | Loss 1.1001 | TrainAcc 0.426 | ValAcc 0.467
# Epoch   90 | Loss 1.0694 | TrainAcc 0.434 | ValAcc 0.467
# Epoch  100 | Loss 1.0380 | TrainAcc 0.449 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.366
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2160 | TrainAcc 0.338 | ValAcc 0.400
# Epoch   10 | Loss 0.9130 | TrainAcc 0.596 | ValAcc 0.467
# Epoch   20 | Loss 0.7285 | TrainAcc 0.787 | ValAcc 0.600
# Epoch   30 | Loss 0.6292 | TrainAcc 0.890 | ValAcc 0.667
# Epoch   40 | Loss 0.5750 | TrainAcc 0.926 | ValAcc 0.667
# Epoch   50 | Loss 0.5372 | TrainAcc 0.949 | ValAcc 0.600
# Epoch   60 | Loss 0.5083 | TrainAcc 0.971 | ValAcc 0.667
# Epoch   70 | Loss 0.4884 | TrainAcc 0.993 | ValAcc 0.667
# Epoch   80 | Loss 0.4774 | TrainAcc 1.000 | ValAcc 0.667
# Epoch   90 | Loss 0.4716 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  100 | Loss 0.4688 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  110 | Loss 0.4671 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  120 | Loss 0.4659 | TrainAcc 1.000 | ValAcc 0.667
# Early stop triggered.
#
# Best ValAcc 0.733 | TestAcc 0.442
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.9169 | TrainAcc 0.544 | ValAcc 0.600
# Epoch   10 | Loss 0.8477 | TrainAcc 0.669 | ValAcc 0.667
# Epoch   20 | Loss 0.8300 | TrainAcc 0.669 | ValAcc 0.667
# Epoch   30 | Loss 0.8135 | TrainAcc 0.684 | ValAcc 0.667
# Epoch   40 | Loss 0.7985 | TrainAcc 0.691 | ValAcc 0.667
# Epoch   50 | Loss 0.7849 | TrainAcc 0.691 | ValAcc 0.667
# Epoch   60 | Loss 0.7724 | TrainAcc 0.691 | ValAcc 0.667
# Epoch   70 | Loss 0.7608 | TrainAcc 0.706 | ValAcc 0.667
# Epoch   80 | Loss 0.7499 | TrainAcc 0.713 | ValAcc 0.667
# Epoch   90 | Loss 0.7394 | TrainAcc 0.779 | ValAcc 0.667
# Epoch  100 | Loss 0.7293 | TrainAcc 0.838 | ValAcc 0.667
# Early stop triggered.
#
# Best ValAcc 0.733 | TestAcc 0.524
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1962 | TrainAcc 0.316 | ValAcc 0.533
# Epoch   10 | Loss 0.9166 | TrainAcc 0.574 | ValAcc 0.600
# Epoch   20 | Loss 0.7482 | TrainAcc 0.735 | ValAcc 0.533
# Epoch   30 | Loss 0.6381 | TrainAcc 0.882 | ValAcc 0.533
# Epoch   40 | Loss 0.5710 | TrainAcc 0.941 | ValAcc 0.467
# Epoch   50 | Loss 0.5273 | TrainAcc 0.971 | ValAcc 0.467
# Epoch   60 | Loss 0.5008 | TrainAcc 0.985 | ValAcc 0.533
# Epoch   70 | Loss 0.4877 | TrainAcc 0.993 | ValAcc 0.533
# Epoch   80 | Loss 0.4806 | TrainAcc 0.993 | ValAcc 0.533
# Epoch   90 | Loss 0.4747 | TrainAcc 1.000 | ValAcc 0.533
# Epoch  100 | Loss 0.4716 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  110 | Loss 0.4698 | TrainAcc 1.000 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.667 | TestAcc 0.429
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.8962 | TrainAcc 0.588 | ValAcc 0.400
# Epoch   10 | Loss 0.7984 | TrainAcc 0.610 | ValAcc 0.400
# Epoch   20 | Loss 0.7805 | TrainAcc 0.640 | ValAcc 0.400
# Epoch   30 | Loss 0.7638 | TrainAcc 0.750 | ValAcc 0.400
# Epoch   40 | Loss 0.7488 | TrainAcc 0.919 | ValAcc 0.400
# Epoch   50 | Loss 0.7349 | TrainAcc 0.919 | ValAcc 0.400
# Epoch   60 | Loss 0.7218 | TrainAcc 0.919 | ValAcc 0.467
# Epoch   70 | Loss 0.7101 | TrainAcc 0.919 | ValAcc 0.467
# Epoch   80 | Loss 0.6994 | TrainAcc 0.926 | ValAcc 0.467
# Epoch   90 | Loss 0.6895 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  100 | Loss 0.6802 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  110 | Loss 0.6714 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  120 | Loss 0.6630 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  130 | Loss 0.6549 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  140 | Loss 0.6471 | TrainAcc 0.926 | ValAcc 0.467
# Epoch  150 | Loss 0.6396 | TrainAcc 0.926 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.560
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2233 | TrainAcc 0.279 | ValAcc 0.533
# Epoch   10 | Loss 0.9291 | TrainAcc 0.603 | ValAcc 0.600
# Epoch   20 | Loss 0.7425 | TrainAcc 0.787 | ValAcc 0.467
# Epoch   30 | Loss 0.6168 | TrainAcc 0.875 | ValAcc 0.533
# Epoch   40 | Loss 0.5568 | TrainAcc 0.934 | ValAcc 0.467
# Epoch   50 | Loss 0.5295 | TrainAcc 0.949 | ValAcc 0.467
# Epoch   60 | Loss 0.5131 | TrainAcc 0.949 | ValAcc 0.467
# Epoch   70 | Loss 0.4961 | TrainAcc 0.963 | ValAcc 0.533
# Epoch   80 | Loss 0.4892 | TrainAcc 0.963 | ValAcc 0.533
# Epoch   90 | Loss 0.4856 | TrainAcc 0.971 | ValAcc 0.533
# Epoch  100 | Loss 0.4835 | TrainAcc 0.971 | ValAcc 0.600
# Epoch  110 | Loss 0.4819 | TrainAcc 0.971 | ValAcc 0.600
# Epoch  120 | Loss 0.4805 | TrainAcc 0.971 | ValAcc 0.600
# Epoch  130 | Loss 0.4793 | TrainAcc 0.971 | ValAcc 0.533
# Epoch  140 | Loss 0.4781 | TrainAcc 0.971 | ValAcc 0.600
# Epoch  150 | Loss 0.4769 | TrainAcc 0.971 | ValAcc 0.600
# Epoch  160 | Loss 0.4762 | TrainAcc 0.985 | ValAcc 0.600
# Epoch  170 | Loss 0.4753 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  180 | Loss 0.4746 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  190 | Loss 0.4740 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  200 | Loss 0.4735 | TrainAcc 1.000 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.667 | TestAcc 0.474
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.9164 | TrainAcc 0.559 | ValAcc 0.400
# Epoch   10 | Loss 0.8309 | TrainAcc 0.721 | ValAcc 0.467
# Epoch   20 | Loss 0.8104 | TrainAcc 0.662 | ValAcc 0.467
# Epoch   30 | Loss 0.7927 | TrainAcc 0.706 | ValAcc 0.467
# Epoch   40 | Loss 0.7769 | TrainAcc 0.721 | ValAcc 0.467
# Epoch   50 | Loss 0.7627 | TrainAcc 0.728 | ValAcc 0.467
# Epoch   60 | Loss 0.7500 | TrainAcc 0.735 | ValAcc 0.467
# Epoch   70 | Loss 0.7386 | TrainAcc 0.735 | ValAcc 0.467
# Epoch   80 | Loss 0.7285 | TrainAcc 0.735 | ValAcc 0.467
# Epoch   90 | Loss 0.7193 | TrainAcc 0.743 | ValAcc 0.467
# Epoch  100 | Loss 0.7110 | TrainAcc 0.743 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.505
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2516 | TrainAcc 0.309 | ValAcc 0.067
# Epoch   10 | Loss 0.8990 | TrainAcc 0.610 | ValAcc 0.333
# Epoch   20 | Loss 0.7463 | TrainAcc 0.735 | ValAcc 0.400
# Epoch   30 | Loss 0.6609 | TrainAcc 0.809 | ValAcc 0.400
# Epoch   40 | Loss 0.5939 | TrainAcc 0.897 | ValAcc 0.400
# Epoch   50 | Loss 0.5589 | TrainAcc 0.919 | ValAcc 0.467
# Epoch   60 | Loss 0.5350 | TrainAcc 0.949 | ValAcc 0.533
# Epoch   70 | Loss 0.5198 | TrainAcc 0.971 | ValAcc 0.533
# Epoch   80 | Loss 0.5100 | TrainAcc 0.978 | ValAcc 0.533
# Epoch   90 | Loss 0.5028 | TrainAcc 0.978 | ValAcc 0.600
# Epoch  100 | Loss 0.4989 | TrainAcc 0.978 | ValAcc 0.600
# Epoch  110 | Loss 0.4959 | TrainAcc 0.978 | ValAcc 0.600
# Epoch  120 | Loss 0.4934 | TrainAcc 0.978 | ValAcc 0.600
# Epoch  130 | Loss 0.4903 | TrainAcc 0.978 | ValAcc 0.533
# Epoch  140 | Loss 0.4865 | TrainAcc 0.978 | ValAcc 0.533
# Epoch  150 | Loss 0.4830 | TrainAcc 0.978 | ValAcc 0.533
# Epoch  160 | Loss 0.4796 | TrainAcc 0.993 | ValAcc 0.533
# Epoch  170 | Loss 0.4760 | TrainAcc 0.993 | ValAcc 0.533
# Epoch  180 | Loss 0.4737 | TrainAcc 0.993 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.430
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.9992 | TrainAcc 0.478 | ValAcc 0.600
# Epoch   10 | Loss 0.9395 | TrainAcc 0.603 | ValAcc 0.600
# Epoch   20 | Loss 0.9180 | TrainAcc 0.603 | ValAcc 0.600
# Epoch   30 | Loss 0.8975 | TrainAcc 0.603 | ValAcc 0.600
# Epoch   40 | Loss 0.8780 | TrainAcc 0.618 | ValAcc 0.600
# Epoch   50 | Loss 0.8595 | TrainAcc 0.618 | ValAcc 0.600
# Epoch   60 | Loss 0.8419 | TrainAcc 0.721 | ValAcc 0.600
# Epoch   70 | Loss 0.8251 | TrainAcc 0.824 | ValAcc 0.600
# Epoch   80 | Loss 0.8089 | TrainAcc 0.860 | ValAcc 0.600
# Epoch   90 | Loss 0.7934 | TrainAcc 0.882 | ValAcc 0.600
# Epoch  100 | Loss 0.7785 | TrainAcc 0.904 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.526
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1504 | TrainAcc 0.390 | ValAcc 0.267
# Epoch   10 | Loss 0.8654 | TrainAcc 0.699 | ValAcc 0.333
# Epoch   20 | Loss 0.6990 | TrainAcc 0.809 | ValAcc 0.267
# Epoch   30 | Loss 0.6056 | TrainAcc 0.919 | ValAcc 0.267
# Epoch   40 | Loss 0.5533 | TrainAcc 0.941 | ValAcc 0.267
# Epoch   50 | Loss 0.5211 | TrainAcc 0.971 | ValAcc 0.267
# Epoch   60 | Loss 0.5031 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   70 | Loss 0.4921 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   80 | Loss 0.4843 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   90 | Loss 0.4785 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  100 | Loss 0.4745 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  110 | Loss 0.4718 | TrainAcc 1.000 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.384
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2299 | TrainAcc 0.331 | ValAcc 0.400
# Epoch   10 | Loss 1.1668 | TrainAcc 0.368 | ValAcc 0.467
# Epoch   20 | Loss 1.1469 | TrainAcc 0.368 | ValAcc 0.467
# Epoch   30 | Loss 1.1254 | TrainAcc 0.375 | ValAcc 0.467
# Epoch   40 | Loss 1.1014 | TrainAcc 0.375 | ValAcc 0.467
# Epoch   50 | Loss 1.0739 | TrainAcc 0.382 | ValAcc 0.467
# Epoch   60 | Loss 1.0421 | TrainAcc 0.390 | ValAcc 0.467
# Epoch   70 | Loss 1.0060 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   80 | Loss 0.9662 | TrainAcc 0.485 | ValAcc 0.467
# Epoch   90 | Loss 0.9239 | TrainAcc 0.485 | ValAcc 0.467
# Epoch  100 | Loss 0.8810 | TrainAcc 0.515 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.461
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2497 | TrainAcc 0.265 | ValAcc 0.067
# Epoch   10 | Loss 0.9291 | TrainAcc 0.559 | ValAcc 0.133
# Epoch   20 | Loss 0.7508 | TrainAcc 0.772 | ValAcc 0.200
# Epoch   30 | Loss 0.6532 | TrainAcc 0.882 | ValAcc 0.333
# Epoch   40 | Loss 0.5891 | TrainAcc 0.926 | ValAcc 0.267
# Epoch   50 | Loss 0.5507 | TrainAcc 0.934 | ValAcc 0.333
# Epoch   60 | Loss 0.5255 | TrainAcc 0.949 | ValAcc 0.400
# Epoch   70 | Loss 0.5077 | TrainAcc 0.971 | ValAcc 0.533
# Epoch   80 | Loss 0.4966 | TrainAcc 0.978 | ValAcc 0.533
# Epoch   90 | Loss 0.4890 | TrainAcc 0.985 | ValAcc 0.533
# Epoch  100 | Loss 0.4853 | TrainAcc 0.985 | ValAcc 0.600
# Epoch  110 | Loss 0.4838 | TrainAcc 0.985 | ValAcc 0.600
# Epoch  120 | Loss 0.4826 | TrainAcc 0.985 | ValAcc 0.600
# Epoch  130 | Loss 0.4817 | TrainAcc 0.985 | ValAcc 0.600
# Epoch  140 | Loss 0.4810 | TrainAcc 0.985 | ValAcc 0.533
# Epoch  150 | Loss 0.4804 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  160 | Loss 0.4799 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  170 | Loss 0.4795 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  180 | Loss 0.4791 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  190 | Loss 0.4788 | TrainAcc 0.985 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.486
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2311 | TrainAcc 0.301 | ValAcc 0.267
# Epoch   10 | Loss 1.2296 | TrainAcc 0.324 | ValAcc 0.267
# Epoch   20 | Loss 1.1988 | TrainAcc 0.360 | ValAcc 0.267
# Epoch   30 | Loss 1.1684 | TrainAcc 0.382 | ValAcc 0.267
# Epoch   40 | Loss 1.1380 | TrainAcc 0.404 | ValAcc 0.267
# Epoch   50 | Loss 1.1077 | TrainAcc 0.456 | ValAcc 0.267
# Epoch   60 | Loss 1.0776 | TrainAcc 0.522 | ValAcc 0.267
# Epoch   70 | Loss 1.0479 | TrainAcc 0.529 | ValAcc 0.333
# Epoch   80 | Loss 1.0188 | TrainAcc 0.537 | ValAcc 0.400
# Epoch   90 | Loss 0.9904 | TrainAcc 0.559 | ValAcc 0.467
# Epoch  100 | Loss 0.9629 | TrainAcc 0.618 | ValAcc 0.533
# Epoch  110 | Loss 0.9363 | TrainAcc 0.618 | ValAcc 0.533
# Epoch  120 | Loss 0.9108 | TrainAcc 0.618 | ValAcc 0.467
# Epoch  130 | Loss 0.8865 | TrainAcc 0.625 | ValAcc 0.467
# Epoch  140 | Loss 0.8636 | TrainAcc 0.654 | ValAcc 0.467
# Epoch  150 | Loss 0.8421 | TrainAcc 0.669 | ValAcc 0.467
# Epoch  160 | Loss 0.8222 | TrainAcc 0.691 | ValAcc 0.533
# Epoch  170 | Loss 0.8040 | TrainAcc 0.728 | ValAcc 0.533
# Epoch  180 | Loss 0.7878 | TrainAcc 0.750 | ValAcc 0.533
# Epoch  190 | Loss 0.7737 | TrainAcc 0.765 | ValAcc 0.533
# Epoch  200 | Loss 0.7615 | TrainAcc 0.794 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.505
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1736 | TrainAcc 0.338 | ValAcc 0.467
# Epoch   10 | Loss 0.8624 | TrainAcc 0.640 | ValAcc 0.467
# Epoch   20 | Loss 0.7089 | TrainAcc 0.787 | ValAcc 0.467
# Epoch   30 | Loss 0.6290 | TrainAcc 0.890 | ValAcc 0.400
# Epoch   40 | Loss 0.5829 | TrainAcc 0.919 | ValAcc 0.333
# Epoch   50 | Loss 0.5492 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   60 | Loss 0.5315 | TrainAcc 0.971 | ValAcc 0.333
# Epoch   70 | Loss 0.5192 | TrainAcc 0.971 | ValAcc 0.333
# Epoch   80 | Loss 0.5056 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   90 | Loss 0.4980 | TrainAcc 0.985 | ValAcc 0.333
# Epoch  100 | Loss 0.4946 | TrainAcc 0.985 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.419
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2173 | TrainAcc 0.360 | ValAcc 0.133
# Epoch   10 | Loss 1.1978 | TrainAcc 0.397 | ValAcc 0.267
# Epoch   20 | Loss 1.1784 | TrainAcc 0.397 | ValAcc 0.267
# Epoch   30 | Loss 1.1574 | TrainAcc 0.404 | ValAcc 0.267
# Epoch   40 | Loss 1.1368 | TrainAcc 0.426 | ValAcc 0.267
# Epoch   50 | Loss 1.1178 | TrainAcc 0.449 | ValAcc 0.267
# Epoch   60 | Loss 1.1001 | TrainAcc 0.463 | ValAcc 0.267
# Epoch   70 | Loss 1.0830 | TrainAcc 0.478 | ValAcc 0.267
# Epoch   80 | Loss 1.0664 | TrainAcc 0.522 | ValAcc 0.267
# Epoch   90 | Loss 1.0501 | TrainAcc 0.537 | ValAcc 0.267
# Epoch  100 | Loss 1.0345 | TrainAcc 0.537 | ValAcc 0.267
# Early stop triggered.
#
# Best ValAcc 0.267 | TestAcc 0.426
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2525 | TrainAcc 0.309 | ValAcc 0.200
# Epoch   10 | Loss 0.9739 | TrainAcc 0.566 | ValAcc 0.267
# Epoch   20 | Loss 0.7750 | TrainAcc 0.735 | ValAcc 0.267
# Epoch   30 | Loss 0.6356 | TrainAcc 0.875 | ValAcc 0.333
# Epoch   40 | Loss 0.5663 | TrainAcc 0.963 | ValAcc 0.400
# Epoch   50 | Loss 0.5279 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   60 | Loss 0.5079 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   70 | Loss 0.4957 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   80 | Loss 0.4866 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   90 | Loss 0.4787 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  100 | Loss 0.4724 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  110 | Loss 0.4686 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  120 | Loss 0.4661 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  130 | Loss 0.4652 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  140 | Loss 0.4643 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  150 | Loss 0.4637 | TrainAcc 1.000 | ValAcc 0.467
# Epoch  160 | Loss 0.4634 | TrainAcc 1.000 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.387
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.0327 | TrainAcc 0.353 | ValAcc 0.533
# Epoch   10 | Loss 0.9048 | TrainAcc 0.463 | ValAcc 0.533
# Epoch   20 | Loss 0.8710 | TrainAcc 0.559 | ValAcc 0.533
# Epoch   30 | Loss 0.8448 | TrainAcc 0.559 | ValAcc 0.533
# Epoch   40 | Loss 0.8250 | TrainAcc 0.559 | ValAcc 0.533
# Epoch   50 | Loss 0.8092 | TrainAcc 0.574 | ValAcc 0.533
# Epoch   60 | Loss 0.7951 | TrainAcc 0.581 | ValAcc 0.533
# Epoch   70 | Loss 0.7817 | TrainAcc 0.581 | ValAcc 0.533
# Epoch   80 | Loss 0.7688 | TrainAcc 0.610 | ValAcc 0.533
# Epoch   90 | Loss 0.7562 | TrainAcc 0.662 | ValAcc 0.533
# Epoch  100 | Loss 0.7440 | TrainAcc 0.721 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.455
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2390 | TrainAcc 0.294 | ValAcc 0.400
# Epoch   10 | Loss 0.9810 | TrainAcc 0.522 | ValAcc 0.333
# Epoch   20 | Loss 0.7959 | TrainAcc 0.735 | ValAcc 0.267
# Epoch   30 | Loss 0.6502 | TrainAcc 0.890 | ValAcc 0.267
# Epoch   40 | Loss 0.5639 | TrainAcc 0.956 | ValAcc 0.533
# Epoch   50 | Loss 0.5255 | TrainAcc 0.978 | ValAcc 0.533
# Epoch   60 | Loss 0.5070 | TrainAcc 0.985 | ValAcc 0.467
# Epoch   70 | Loss 0.4960 | TrainAcc 0.985 | ValAcc 0.467
# Epoch   80 | Loss 0.4885 | TrainAcc 0.985 | ValAcc 0.467
# Epoch   90 | Loss 0.4827 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  100 | Loss 0.4787 | TrainAcc 0.985 | ValAcc 0.467
# Epoch  110 | Loss 0.4755 | TrainAcc 0.985 | ValAcc 0.400
# Epoch  120 | Loss 0.4727 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  130 | Loss 0.4688 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.453
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2554 | TrainAcc 0.154 | ValAcc 0.267
# Epoch   10 | Loss 1.2104 | TrainAcc 0.191 | ValAcc 0.400
# Epoch   20 | Loss 1.1821 | TrainAcc 0.206 | ValAcc 0.467
# Epoch   30 | Loss 1.1527 | TrainAcc 0.228 | ValAcc 0.467
# Epoch   40 | Loss 1.1226 | TrainAcc 0.250 | ValAcc 0.467
# Epoch   50 | Loss 1.0924 | TrainAcc 0.279 | ValAcc 0.533
# Epoch   60 | Loss 1.0624 | TrainAcc 0.287 | ValAcc 0.533
# Epoch   70 | Loss 1.0329 | TrainAcc 0.287 | ValAcc 0.533
# Epoch   80 | Loss 1.0042 | TrainAcc 0.287 | ValAcc 0.533
# Epoch   90 | Loss 0.9763 | TrainAcc 0.346 | ValAcc 0.533
# Epoch  100 | Loss 0.9490 | TrainAcc 0.449 | ValAcc 0.533
# Epoch  110 | Loss 0.9233 | TrainAcc 0.537 | ValAcc 0.533
# Epoch  120 | Loss 0.8994 | TrainAcc 0.559 | ValAcc 0.533
# Epoch  130 | Loss 0.8773 | TrainAcc 0.581 | ValAcc 0.533
# Epoch  140 | Loss 0.8570 | TrainAcc 0.603 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.449
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1959 | TrainAcc 0.360 | ValAcc 0.267
# Epoch   10 | Loss 0.8486 | TrainAcc 0.684 | ValAcc 0.267
# Epoch   20 | Loss 0.6895 | TrainAcc 0.816 | ValAcc 0.467
# Epoch   30 | Loss 0.6178 | TrainAcc 0.890 | ValAcc 0.333
# Epoch   40 | Loss 0.5668 | TrainAcc 0.926 | ValAcc 0.333
# Epoch   50 | Loss 0.5351 | TrainAcc 0.956 | ValAcc 0.333
# Epoch   60 | Loss 0.5153 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   70 | Loss 0.5063 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   80 | Loss 0.4995 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   90 | Loss 0.4925 | TrainAcc 0.978 | ValAcc 0.333
# Epoch  100 | Loss 0.4850 | TrainAcc 0.985 | ValAcc 0.333
# Epoch  110 | Loss 0.4817 | TrainAcc 0.993 | ValAcc 0.267
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.395
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.8942 | TrainAcc 0.610 | ValAcc 0.400
# Epoch   10 | Loss 0.8633 | TrainAcc 0.610 | ValAcc 0.400
# Epoch   20 | Loss 0.8555 | TrainAcc 0.618 | ValAcc 0.400
# Epoch   30 | Loss 0.8480 | TrainAcc 0.618 | ValAcc 0.467
# Epoch   40 | Loss 0.8404 | TrainAcc 0.618 | ValAcc 0.467
# Epoch   50 | Loss 0.8326 | TrainAcc 0.618 | ValAcc 0.467
# Epoch   60 | Loss 0.8244 | TrainAcc 0.618 | ValAcc 0.467
# Epoch   70 | Loss 0.8156 | TrainAcc 0.618 | ValAcc 0.600
# Epoch   80 | Loss 0.8060 | TrainAcc 0.632 | ValAcc 0.667
# Epoch   90 | Loss 0.7955 | TrainAcc 0.669 | ValAcc 0.667
# Epoch  100 | Loss 0.7837 | TrainAcc 0.684 | ValAcc 0.667
# Epoch  110 | Loss 0.7704 | TrainAcc 0.699 | ValAcc 0.667
# Epoch  120 | Loss 0.7555 | TrainAcc 0.699 | ValAcc 0.667
# Epoch  130 | Loss 0.7385 | TrainAcc 0.713 | ValAcc 0.667
# Epoch  140 | Loss 0.7214 | TrainAcc 0.735 | ValAcc 0.733
# Epoch  150 | Loss 0.7046 | TrainAcc 0.757 | ValAcc 0.733
# Epoch  160 | Loss 0.6864 | TrainAcc 0.816 | ValAcc 0.733
# Epoch  170 | Loss 0.6692 | TrainAcc 0.838 | ValAcc 0.733
# Epoch  180 | Loss 0.6502 | TrainAcc 0.846 | ValAcc 0.667
# Epoch  190 | Loss 0.6331 | TrainAcc 0.853 | ValAcc 0.667
# Epoch  200 | Loss 0.6198 | TrainAcc 0.853 | ValAcc 0.667
# Epoch  210 | Loss 0.6111 | TrainAcc 0.853 | ValAcc 0.667
# Epoch  220 | Loss 0.6062 | TrainAcc 0.853 | ValAcc 0.667
# Epoch  230 | Loss 0.6017 | TrainAcc 0.853 | ValAcc 0.667
# Early stop triggered.
#
# Best ValAcc 0.733 | TestAcc 0.521
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2317 | TrainAcc 0.331 | ValAcc 0.333
# Epoch   10 | Loss 0.9435 | TrainAcc 0.588 | ValAcc 0.400
# Epoch   20 | Loss 0.7625 | TrainAcc 0.757 | ValAcc 0.400
# Epoch   30 | Loss 0.6549 | TrainAcc 0.868 | ValAcc 0.467
# Epoch   40 | Loss 0.5891 | TrainAcc 0.919 | ValAcc 0.533
# Epoch   50 | Loss 0.5447 | TrainAcc 0.956 | ValAcc 0.400
# Epoch   60 | Loss 0.5185 | TrainAcc 0.971 | ValAcc 0.400
# Epoch   70 | Loss 0.5020 | TrainAcc 0.971 | ValAcc 0.400
# Epoch   80 | Loss 0.4924 | TrainAcc 0.978 | ValAcc 0.400
# Epoch   90 | Loss 0.4825 | TrainAcc 0.985 | ValAcc 0.400
# Epoch  100 | Loss 0.4773 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  110 | Loss 0.4726 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  120 | Loss 0.4681 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  130 | Loss 0.4670 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.378
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2943 | TrainAcc 0.338 | ValAcc 0.267
# Epoch   10 | Loss 1.2167 | TrainAcc 0.529 | ValAcc 0.267
# Epoch   20 | Loss 1.1735 | TrainAcc 0.544 | ValAcc 0.333
# Epoch   30 | Loss 1.1314 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   40 | Loss 1.0995 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   50 | Loss 1.0799 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   60 | Loss 1.0665 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   70 | Loss 1.0547 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   80 | Loss 1.0423 | TrainAcc 0.669 | ValAcc 0.333
# Epoch   90 | Loss 1.0281 | TrainAcc 0.669 | ValAcc 0.333
# Epoch  100 | Loss 1.0109 | TrainAcc 0.669 | ValAcc 0.333
# Epoch  110 | Loss 0.9893 | TrainAcc 0.669 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.333 | TestAcc 0.449
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2255 | TrainAcc 0.324 | ValAcc 0.400
# Epoch   10 | Loss 0.9207 | TrainAcc 0.610 | ValAcc 0.533
# Epoch   20 | Loss 0.7411 | TrainAcc 0.794 | ValAcc 0.400
# Epoch   30 | Loss 0.6390 | TrainAcc 0.868 | ValAcc 0.333
# Epoch   40 | Loss 0.5780 | TrainAcc 0.934 | ValAcc 0.333
# Epoch   50 | Loss 0.5350 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   60 | Loss 0.5038 | TrainAcc 0.985 | ValAcc 0.267
# Epoch   70 | Loss 0.4861 | TrainAcc 0.985 | ValAcc 0.333
# Epoch   80 | Loss 0.4741 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   90 | Loss 0.4700 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  100 | Loss 0.4684 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.422
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2071 | TrainAcc 0.265 | ValAcc 0.467
# Epoch   10 | Loss 1.1789 | TrainAcc 0.301 | ValAcc 0.333
# Epoch   20 | Loss 1.1542 | TrainAcc 0.353 | ValAcc 0.333
# Epoch   30 | Loss 1.1295 | TrainAcc 0.397 | ValAcc 0.333
# Epoch   40 | Loss 1.1047 | TrainAcc 0.426 | ValAcc 0.333
# Epoch   50 | Loss 1.0798 | TrainAcc 0.441 | ValAcc 0.333
# Epoch   60 | Loss 1.0552 | TrainAcc 0.456 | ValAcc 0.333
# Epoch   70 | Loss 1.0310 | TrainAcc 0.463 | ValAcc 0.333
# Epoch   80 | Loss 1.0076 | TrainAcc 0.478 | ValAcc 0.333
# Epoch   90 | Loss 0.9855 | TrainAcc 0.507 | ValAcc 0.333
# Epoch  100 | Loss 0.9646 | TrainAcc 0.522 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.473
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1922 | TrainAcc 0.353 | ValAcc 0.333
# Epoch   10 | Loss 0.8651 | TrainAcc 0.647 | ValAcc 0.467
# Epoch   20 | Loss 0.6798 | TrainAcc 0.853 | ValAcc 0.400
# Epoch   30 | Loss 0.5944 | TrainAcc 0.926 | ValAcc 0.400
# Epoch   40 | Loss 0.5478 | TrainAcc 0.941 | ValAcc 0.333
# Epoch   50 | Loss 0.5127 | TrainAcc 0.985 | ValAcc 0.333
# Epoch   60 | Loss 0.4901 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   70 | Loss 0.4814 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   80 | Loss 0.4756 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   90 | Loss 0.4717 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  100 | Loss 0.4695 | TrainAcc 1.000 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.433
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.0715 | TrainAcc 0.463 | ValAcc 0.333
# Epoch   10 | Loss 1.0004 | TrainAcc 0.515 | ValAcc 0.467
# Epoch   20 | Loss 0.9710 | TrainAcc 0.515 | ValAcc 0.533
# Epoch   30 | Loss 0.9361 | TrainAcc 0.529 | ValAcc 0.600
# Epoch   40 | Loss 0.8852 | TrainAcc 0.544 | ValAcc 0.600
# Epoch   50 | Loss 0.8270 | TrainAcc 0.596 | ValAcc 0.600
# Epoch   60 | Loss 0.7880 | TrainAcc 0.632 | ValAcc 0.600
# Epoch   70 | Loss 0.7665 | TrainAcc 0.669 | ValAcc 0.600
# Epoch   80 | Loss 0.7507 | TrainAcc 0.684 | ValAcc 0.600
# Epoch   90 | Loss 0.7374 | TrainAcc 0.713 | ValAcc 0.600
# Epoch  100 | Loss 0.7251 | TrainAcc 0.728 | ValAcc 0.600
# Epoch  110 | Loss 0.7133 | TrainAcc 0.735 | ValAcc 0.600
# Epoch  120 | Loss 0.7020 | TrainAcc 0.750 | ValAcc 0.600
# Epoch  130 | Loss 0.6911 | TrainAcc 0.750 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.493
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2298 | TrainAcc 0.316 | ValAcc 0.333
# Epoch   10 | Loss 0.9052 | TrainAcc 0.588 | ValAcc 0.400
# Epoch   20 | Loss 0.7249 | TrainAcc 0.750 | ValAcc 0.467
# Epoch   30 | Loss 0.6200 | TrainAcc 0.890 | ValAcc 0.467
# Epoch   40 | Loss 0.5565 | TrainAcc 0.956 | ValAcc 0.400
# Epoch   50 | Loss 0.5227 | TrainAcc 0.963 | ValAcc 0.533
# Epoch   60 | Loss 0.5030 | TrainAcc 0.971 | ValAcc 0.667
# Epoch   70 | Loss 0.4873 | TrainAcc 0.978 | ValAcc 0.667
# Epoch   80 | Loss 0.4738 | TrainAcc 1.000 | ValAcc 0.600
# Epoch   90 | Loss 0.4668 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  100 | Loss 0.4656 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  110 | Loss 0.4647 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  120 | Loss 0.4640 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  130 | Loss 0.4635 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  140 | Loss 0.4632 | TrainAcc 1.000 | ValAcc 0.600
# Epoch  150 | Loss 0.4630 | TrainAcc 1.000 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.667 | TestAcc 0.478
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1573 | TrainAcc 0.382 | ValAcc 0.400
# Epoch   10 | Loss 1.0817 | TrainAcc 0.426 | ValAcc 0.533
# Epoch   20 | Loss 1.0605 | TrainAcc 0.434 | ValAcc 0.533
# Epoch   30 | Loss 1.0395 | TrainAcc 0.441 | ValAcc 0.533
# Epoch   40 | Loss 1.0185 | TrainAcc 0.441 | ValAcc 0.533
# Epoch   50 | Loss 0.9965 | TrainAcc 0.449 | ValAcc 0.533
# Epoch   60 | Loss 0.9735 | TrainAcc 0.463 | ValAcc 0.533
# Epoch   70 | Loss 0.9493 | TrainAcc 0.463 | ValAcc 0.533
# Epoch   80 | Loss 0.9243 | TrainAcc 0.522 | ValAcc 0.533
# Epoch   90 | Loss 0.8987 | TrainAcc 0.551 | ValAcc 0.533
# Epoch  100 | Loss 0.8730 | TrainAcc 0.566 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.455
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2580 | TrainAcc 0.316 | ValAcc 0.400
# Epoch   10 | Loss 0.9828 | TrainAcc 0.566 | ValAcc 0.400
# Epoch   20 | Loss 0.8126 | TrainAcc 0.706 | ValAcc 0.333
# Epoch   30 | Loss 0.6994 | TrainAcc 0.816 | ValAcc 0.267
# Epoch   40 | Loss 0.6199 | TrainAcc 0.882 | ValAcc 0.267
# Epoch   50 | Loss 0.5651 | TrainAcc 0.926 | ValAcc 0.400
# Epoch   60 | Loss 0.5289 | TrainAcc 0.956 | ValAcc 0.400
# Epoch   70 | Loss 0.5048 | TrainAcc 0.985 | ValAcc 0.400
# Epoch   80 | Loss 0.4892 | TrainAcc 0.985 | ValAcc 0.400
# Epoch   90 | Loss 0.4784 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  100 | Loss 0.4697 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.440
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.0789 | TrainAcc 0.471 | ValAcc 0.533
# Epoch   10 | Loss 1.0017 | TrainAcc 0.507 | ValAcc 0.600
# Epoch   20 | Loss 0.9775 | TrainAcc 0.529 | ValAcc 0.600
# Epoch   30 | Loss 0.9577 | TrainAcc 0.544 | ValAcc 0.600
# Epoch   40 | Loss 0.9399 | TrainAcc 0.566 | ValAcc 0.600
# Epoch   50 | Loss 0.9240 | TrainAcc 0.566 | ValAcc 0.600
# Epoch   60 | Loss 0.9095 | TrainAcc 0.566 | ValAcc 0.600
# Epoch   70 | Loss 0.8958 | TrainAcc 0.566 | ValAcc 0.533
# Epoch   80 | Loss 0.8827 | TrainAcc 0.566 | ValAcc 0.533
# Epoch   90 | Loss 0.8700 | TrainAcc 0.566 | ValAcc 0.533
# Epoch  100 | Loss 0.8572 | TrainAcc 0.566 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.478
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2145 | TrainAcc 0.287 | ValAcc 0.133
# Epoch   10 | Loss 0.9380 | TrainAcc 0.529 | ValAcc 0.267
# Epoch   20 | Loss 0.7510 | TrainAcc 0.779 | ValAcc 0.333
# Epoch   30 | Loss 0.6422 | TrainAcc 0.860 | ValAcc 0.400
# Epoch   40 | Loss 0.5749 | TrainAcc 0.949 | ValAcc 0.400
# Epoch   50 | Loss 0.5328 | TrainAcc 0.978 | ValAcc 0.400
# Epoch   60 | Loss 0.5061 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   70 | Loss 0.4892 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   80 | Loss 0.4791 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   90 | Loss 0.4740 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  100 | Loss 0.4707 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  110 | Loss 0.4680 | TrainAcc 0.993 | ValAcc 0.333
# Epoch  120 | Loss 0.4666 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  130 | Loss 0.4656 | TrainAcc 1.000 | ValAcc 0.267
# Epoch  140 | Loss 0.4644 | TrainAcc 1.000 | ValAcc 0.267
# Epoch  150 | Loss 0.4631 | TrainAcc 1.000 | ValAcc 0.267
# Epoch  160 | Loss 0.4624 | TrainAcc 1.000 | ValAcc 0.267
# Epoch  170 | Loss 0.4624 | TrainAcc 1.000 | ValAcc 0.267
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.369
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1228 | TrainAcc 0.412 | ValAcc 0.400
# Epoch   10 | Loss 1.0986 | TrainAcc 0.412 | ValAcc 0.400
# Epoch   20 | Loss 1.0776 | TrainAcc 0.412 | ValAcc 0.400
# Epoch   30 | Loss 1.0551 | TrainAcc 0.412 | ValAcc 0.400
# Epoch   40 | Loss 1.0309 | TrainAcc 0.419 | ValAcc 0.400
# Epoch   50 | Loss 1.0054 | TrainAcc 0.434 | ValAcc 0.400
# Epoch   60 | Loss 0.9789 | TrainAcc 0.463 | ValAcc 0.400
# Epoch   70 | Loss 0.9514 | TrainAcc 0.493 | ValAcc 0.400
# Epoch   80 | Loss 0.9231 | TrainAcc 0.654 | ValAcc 0.400
# Epoch   90 | Loss 0.8946 | TrainAcc 0.699 | ValAcc 0.400
# Epoch  100 | Loss 0.8657 | TrainAcc 0.757 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.459
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1485 | TrainAcc 0.375 | ValAcc 0.267
# Epoch   10 | Loss 0.8339 | TrainAcc 0.669 | ValAcc 0.400
# Epoch   20 | Loss 0.6707 | TrainAcc 0.831 | ValAcc 0.267
# Epoch   30 | Loss 0.5891 | TrainAcc 0.926 | ValAcc 0.333
# Epoch   40 | Loss 0.5424 | TrainAcc 0.941 | ValAcc 0.333
# Epoch   50 | Loss 0.5142 | TrainAcc 0.971 | ValAcc 0.333
# Epoch   60 | Loss 0.4960 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   70 | Loss 0.4840 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   80 | Loss 0.4742 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   90 | Loss 0.4694 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  100 | Loss 0.4664 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.459
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.8801 | TrainAcc 0.596 | ValAcc 0.400
# Epoch   10 | Loss 0.8094 | TrainAcc 0.735 | ValAcc 0.467
# Epoch   20 | Loss 0.7925 | TrainAcc 0.757 | ValAcc 0.467
# Epoch   30 | Loss 0.7781 | TrainAcc 0.772 | ValAcc 0.533
# Epoch   40 | Loss 0.7649 | TrainAcc 0.794 | ValAcc 0.533
# Epoch   50 | Loss 0.7525 | TrainAcc 0.794 | ValAcc 0.533
# Epoch   60 | Loss 0.7405 | TrainAcc 0.794 | ValAcc 0.533
# Epoch   70 | Loss 0.7287 | TrainAcc 0.809 | ValAcc 0.533
# Epoch   80 | Loss 0.7170 | TrainAcc 0.809 | ValAcc 0.600
# Epoch   90 | Loss 0.7051 | TrainAcc 0.824 | ValAcc 0.600
# Epoch  100 | Loss 0.6931 | TrainAcc 0.824 | ValAcc 0.600
# Epoch  110 | Loss 0.6809 | TrainAcc 0.860 | ValAcc 0.600
# Epoch  120 | Loss 0.6685 | TrainAcc 0.882 | ValAcc 0.600
# Epoch  130 | Loss 0.6561 | TrainAcc 0.919 | ValAcc 0.600
# Epoch  140 | Loss 0.6440 | TrainAcc 0.926 | ValAcc 0.600
# Epoch  150 | Loss 0.6324 | TrainAcc 0.934 | ValAcc 0.600
# Epoch  160 | Loss 0.6217 | TrainAcc 0.941 | ValAcc 0.600
# Epoch  170 | Loss 0.6123 | TrainAcc 0.949 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.561
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1863 | TrainAcc 0.390 | ValAcc 0.267
# Epoch   10 | Loss 0.8816 | TrainAcc 0.654 | ValAcc 0.267
# Epoch   20 | Loss 0.6799 | TrainAcc 0.809 | ValAcc 0.400
# Epoch   30 | Loss 0.5688 | TrainAcc 0.919 | ValAcc 0.400
# Epoch   40 | Loss 0.5160 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   50 | Loss 0.4950 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   60 | Loss 0.4832 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   70 | Loss 0.4751 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   80 | Loss 0.4700 | TrainAcc 1.000 | ValAcc 0.400
# Epoch   90 | Loss 0.4679 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  100 | Loss 0.4667 | TrainAcc 1.000 | ValAcc 0.400
# Epoch  110 | Loss 0.4658 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.469
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1167 | TrainAcc 0.419 | ValAcc 0.600
# Epoch   10 | Loss 1.0330 | TrainAcc 0.713 | ValAcc 0.467
# Epoch   20 | Loss 1.0124 | TrainAcc 0.713 | ValAcc 0.533
# Epoch   30 | Loss 0.9883 | TrainAcc 0.728 | ValAcc 0.533
# Epoch   40 | Loss 0.9595 | TrainAcc 0.728 | ValAcc 0.533
# Epoch   50 | Loss 0.9250 | TrainAcc 0.743 | ValAcc 0.533
# Epoch   60 | Loss 0.8862 | TrainAcc 0.750 | ValAcc 0.467
# Epoch   70 | Loss 0.8496 | TrainAcc 0.757 | ValAcc 0.533
# Epoch   80 | Loss 0.8202 | TrainAcc 0.765 | ValAcc 0.533
# Epoch   90 | Loss 0.7946 | TrainAcc 0.765 | ValAcc 0.533
# Epoch  100 | Loss 0.7738 | TrainAcc 0.772 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.498
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2013 | TrainAcc 0.309 | ValAcc 0.400
# Epoch   10 | Loss 0.8800 | TrainAcc 0.669 | ValAcc 0.467
# Epoch   20 | Loss 0.6899 | TrainAcc 0.831 | ValAcc 0.533
# Epoch   30 | Loss 0.5923 | TrainAcc 0.897 | ValAcc 0.467
# Epoch   40 | Loss 0.5468 | TrainAcc 0.934 | ValAcc 0.333
# Epoch   50 | Loss 0.5190 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   60 | Loss 0.5041 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   70 | Loss 0.4931 | TrainAcc 0.985 | ValAcc 0.267
# Epoch   80 | Loss 0.4854 | TrainAcc 0.985 | ValAcc 0.333
# Epoch   90 | Loss 0.4801 | TrainAcc 0.993 | ValAcc 0.267
# Epoch  100 | Loss 0.4748 | TrainAcc 1.000 | ValAcc 0.267
# Epoch  110 | Loss 0.4711 | TrainAcc 1.000 | ValAcc 0.267
# Early stop triggered.
#
# Best ValAcc 0.533 | TestAcc 0.408
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.3024 | TrainAcc 0.184 | ValAcc 0.333
# Epoch   10 | Loss 1.2242 | TrainAcc 0.309 | ValAcc 0.267
# Epoch   20 | Loss 1.2056 | TrainAcc 0.324 | ValAcc 0.333
# Epoch   30 | Loss 1.1868 | TrainAcc 0.331 | ValAcc 0.333
# Epoch   40 | Loss 1.1676 | TrainAcc 0.331 | ValAcc 0.333
# Epoch   50 | Loss 1.1472 | TrainAcc 0.360 | ValAcc 0.333
# Epoch   60 | Loss 1.1251 | TrainAcc 0.368 | ValAcc 0.333
# Epoch   70 | Loss 1.1006 | TrainAcc 0.375 | ValAcc 0.333
# Epoch   80 | Loss 1.0735 | TrainAcc 0.382 | ValAcc 0.333
# Epoch   90 | Loss 1.0415 | TrainAcc 0.397 | ValAcc 0.333
# Epoch  100 | Loss 1.0039 | TrainAcc 0.404 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.333 | TestAcc 0.316
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1994 | TrainAcc 0.346 | ValAcc 0.533
# Epoch   10 | Loss 0.9069 | TrainAcc 0.588 | ValAcc 0.533
# Epoch   20 | Loss 0.7155 | TrainAcc 0.816 | ValAcc 0.533
# Epoch   30 | Loss 0.6187 | TrainAcc 0.904 | ValAcc 0.533
# Epoch   40 | Loss 0.5645 | TrainAcc 0.934 | ValAcc 0.400
# Epoch   50 | Loss 0.5279 | TrainAcc 0.963 | ValAcc 0.333
# Epoch   60 | Loss 0.5097 | TrainAcc 0.971 | ValAcc 0.333
# Epoch   70 | Loss 0.4941 | TrainAcc 0.978 | ValAcc 0.400
# Epoch   80 | Loss 0.4858 | TrainAcc 0.978 | ValAcc 0.400
# Epoch   90 | Loss 0.4815 | TrainAcc 0.985 | ValAcc 0.400
# Epoch  100 | Loss 0.4780 | TrainAcc 0.993 | ValAcc 0.400
# Epoch  110 | Loss 0.4739 | TrainAcc 1.000 | ValAcc 0.400
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.411
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1514 | TrainAcc 0.316 | ValAcc 0.467
# Epoch   10 | Loss 1.0661 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   20 | Loss 1.0425 | TrainAcc 0.412 | ValAcc 0.467
# Epoch   30 | Loss 1.0170 | TrainAcc 0.426 | ValAcc 0.467
# Epoch   40 | Loss 0.9904 | TrainAcc 0.434 | ValAcc 0.467
# Epoch   50 | Loss 0.9632 | TrainAcc 0.441 | ValAcc 0.467
# Epoch   60 | Loss 0.9358 | TrainAcc 0.449 | ValAcc 0.467
# Epoch   70 | Loss 0.9081 | TrainAcc 0.449 | ValAcc 0.467
# Epoch   80 | Loss 0.8804 | TrainAcc 0.463 | ValAcc 0.467
# Epoch   90 | Loss 0.8533 | TrainAcc 0.485 | ValAcc 0.600
# Epoch  100 | Loss 0.8272 | TrainAcc 0.551 | ValAcc 0.600
# Epoch  110 | Loss 0.8027 | TrainAcc 0.603 | ValAcc 0.600
# Epoch  120 | Loss 0.7800 | TrainAcc 0.706 | ValAcc 0.600
# Epoch  130 | Loss 0.7594 | TrainAcc 0.765 | ValAcc 0.600
# Epoch  140 | Loss 0.7408 | TrainAcc 0.787 | ValAcc 0.600
# Epoch  150 | Loss 0.7241 | TrainAcc 0.801 | ValAcc 0.600
# Epoch  160 | Loss 0.7091 | TrainAcc 0.809 | ValAcc 0.600
# Epoch  170 | Loss 0.6956 | TrainAcc 0.809 | ValAcc 0.600
# Epoch  180 | Loss 0.6833 | TrainAcc 0.816 | ValAcc 0.600
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.535
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1895 | TrainAcc 0.368 | ValAcc 0.467
# Epoch   10 | Loss 0.8804 | TrainAcc 0.588 | ValAcc 0.467
# Epoch   20 | Loss 0.6781 | TrainAcc 0.824 | ValAcc 0.467
# Epoch   30 | Loss 0.5913 | TrainAcc 0.882 | ValAcc 0.533
# Epoch   40 | Loss 0.5418 | TrainAcc 0.934 | ValAcc 0.400
# Epoch   50 | Loss 0.5094 | TrainAcc 0.956 | ValAcc 0.533
# Epoch   60 | Loss 0.4885 | TrainAcc 0.985 | ValAcc 0.533
# Epoch   70 | Loss 0.4784 | TrainAcc 0.993 | ValAcc 0.533
# Epoch   80 | Loss 0.4727 | TrainAcc 1.000 | ValAcc 0.533
# Epoch   90 | Loss 0.4692 | TrainAcc 1.000 | ValAcc 0.533
# Epoch  100 | Loss 0.4674 | TrainAcc 1.000 | ValAcc 0.533
# Epoch  110 | Loss 0.4661 | TrainAcc 1.000 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.478
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2020 | TrainAcc 0.213 | ValAcc 0.400
# Epoch   10 | Loss 1.1316 | TrainAcc 0.294 | ValAcc 0.400
# Epoch   20 | Loss 1.0948 | TrainAcc 0.368 | ValAcc 0.400
# Epoch   30 | Loss 1.0575 | TrainAcc 0.434 | ValAcc 0.467
# Epoch   40 | Loss 1.0203 | TrainAcc 0.478 | ValAcc 0.467
# Epoch   50 | Loss 0.9837 | TrainAcc 0.500 | ValAcc 0.467
# Epoch   60 | Loss 0.9481 | TrainAcc 0.515 | ValAcc 0.467
# Epoch   70 | Loss 0.9165 | TrainAcc 0.515 | ValAcc 0.467
# Epoch   80 | Loss 0.8866 | TrainAcc 0.522 | ValAcc 0.467
# Epoch   90 | Loss 0.8590 | TrainAcc 0.529 | ValAcc 0.467
# Epoch  100 | Loss 0.8333 | TrainAcc 0.551 | ValAcc 0.467
# Epoch  110 | Loss 0.8095 | TrainAcc 0.566 | ValAcc 0.467
# Epoch  120 | Loss 0.7875 | TrainAcc 0.618 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.467 | TestAcc 0.488
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1482 | TrainAcc 0.382 | ValAcc 0.333
# Epoch   10 | Loss 0.8286 | TrainAcc 0.706 | ValAcc 0.533
# Epoch   20 | Loss 0.6529 | TrainAcc 0.831 | ValAcc 0.600
# Epoch   30 | Loss 0.5627 | TrainAcc 0.941 | ValAcc 0.333
# Epoch   40 | Loss 0.5200 | TrainAcc 0.971 | ValAcc 0.400
# Epoch   50 | Loss 0.4957 | TrainAcc 0.985 | ValAcc 0.333
# Epoch   60 | Loss 0.4809 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   70 | Loss 0.4731 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   80 | Loss 0.4689 | TrainAcc 1.000 | ValAcc 0.333
# Epoch   90 | Loss 0.4666 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  100 | Loss 0.4653 | TrainAcc 1.000 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.461
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.0324 | TrainAcc 0.419 | ValAcc 0.400
# Epoch   10 | Loss 1.0134 | TrainAcc 0.449 | ValAcc 0.267
# Epoch   20 | Loss 0.9927 | TrainAcc 0.456 | ValAcc 0.267
# Epoch   30 | Loss 0.9719 | TrainAcc 0.456 | ValAcc 0.267
# Epoch   40 | Loss 0.9508 | TrainAcc 0.471 | ValAcc 0.200
# Epoch   50 | Loss 0.9295 | TrainAcc 0.485 | ValAcc 0.200
# Epoch   60 | Loss 0.9082 | TrainAcc 0.603 | ValAcc 0.200
# Epoch   70 | Loss 0.8866 | TrainAcc 0.603 | ValAcc 0.200
# Epoch   80 | Loss 0.8649 | TrainAcc 0.603 | ValAcc 0.200
# Epoch   90 | Loss 0.8433 | TrainAcc 0.713 | ValAcc 0.200
# Epoch  100 | Loss 0.8222 | TrainAcc 0.713 | ValAcc 0.200
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.389
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1746 | TrainAcc 0.390 | ValAcc 0.467
# Epoch   10 | Loss 0.8879 | TrainAcc 0.662 | ValAcc 0.533
# Epoch   20 | Loss 0.7096 | TrainAcc 0.824 | ValAcc 0.467
# Epoch   30 | Loss 0.6299 | TrainAcc 0.875 | ValAcc 0.400
# Epoch   40 | Loss 0.5788 | TrainAcc 0.904 | ValAcc 0.400
# Epoch   50 | Loss 0.5333 | TrainAcc 0.941 | ValAcc 0.400
# Epoch   60 | Loss 0.5061 | TrainAcc 0.971 | ValAcc 0.400
# Epoch   70 | Loss 0.4926 | TrainAcc 0.985 | ValAcc 0.400
# Epoch   80 | Loss 0.4806 | TrainAcc 0.993 | ValAcc 0.400
# Epoch   90 | Loss 0.4719 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  100 | Loss 0.4690 | TrainAcc 1.000 | ValAcc 0.333
# Epoch  110 | Loss 0.4670 | TrainAcc 1.000 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.400
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 0.9378 | TrainAcc 0.551 | ValAcc 0.467
# Epoch   10 | Loss 0.8787 | TrainAcc 0.581 | ValAcc 0.533
# Epoch   20 | Loss 0.8579 | TrainAcc 0.581 | ValAcc 0.533
# Epoch   30 | Loss 0.8384 | TrainAcc 0.581 | ValAcc 0.533
# Epoch   40 | Loss 0.8189 | TrainAcc 0.625 | ValAcc 0.600
# Epoch   50 | Loss 0.7984 | TrainAcc 0.640 | ValAcc 0.600
# Epoch   60 | Loss 0.7763 | TrainAcc 0.676 | ValAcc 0.600
# Epoch   70 | Loss 0.7523 | TrainAcc 0.809 | ValAcc 0.600
# Epoch   80 | Loss 0.7261 | TrainAcc 0.816 | ValAcc 0.600
# Epoch   90 | Loss 0.6993 | TrainAcc 0.860 | ValAcc 0.600
# Epoch  100 | Loss 0.6781 | TrainAcc 0.897 | ValAcc 0.600
# Epoch  110 | Loss 0.6640 | TrainAcc 0.904 | ValAcc 0.600
# Epoch  120 | Loss 0.6548 | TrainAcc 0.904 | ValAcc 0.600
# Epoch  130 | Loss 0.6485 | TrainAcc 0.904 | ValAcc 0.600
# Epoch  140 | Loss 0.6436 | TrainAcc 0.904 | ValAcc 0.667
# Epoch  150 | Loss 0.6395 | TrainAcc 0.904 | ValAcc 0.667
# Epoch  160 | Loss 0.6358 | TrainAcc 0.912 | ValAcc 0.667
# Epoch  170 | Loss 0.6324 | TrainAcc 0.919 | ValAcc 0.667
# Epoch  180 | Loss 0.6291 | TrainAcc 0.919 | ValAcc 0.667
# Epoch  190 | Loss 0.6260 | TrainAcc 0.919 | ValAcc 0.667
# Epoch  200 | Loss 0.6232 | TrainAcc 0.919 | ValAcc 0.667
# Epoch  210 | Loss 0.6205 | TrainAcc 0.926 | ValAcc 0.667
# Epoch  220 | Loss 0.6180 | TrainAcc 0.926 | ValAcc 0.667
# Epoch  230 | Loss 0.6156 | TrainAcc 0.926 | ValAcc 0.667
# Early stop triggered.
#
# Best ValAcc 0.667 | TestAcc 0.526
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2746 | TrainAcc 0.360 | ValAcc 0.533
# Epoch   10 | Loss 0.9973 | TrainAcc 0.515 | ValAcc 0.667
# Epoch   20 | Loss 0.8109 | TrainAcc 0.713 | ValAcc 0.667
# Epoch   30 | Loss 0.6884 | TrainAcc 0.809 | ValAcc 0.667
# Epoch   40 | Loss 0.5960 | TrainAcc 0.897 | ValAcc 0.667
# Epoch   50 | Loss 0.5400 | TrainAcc 0.934 | ValAcc 0.667
# Epoch   60 | Loss 0.5043 | TrainAcc 0.971 | ValAcc 0.600
# Epoch   70 | Loss 0.4861 | TrainAcc 0.993 | ValAcc 0.667
# Epoch   80 | Loss 0.4764 | TrainAcc 1.000 | ValAcc 0.667
# Epoch   90 | Loss 0.4715 | TrainAcc 1.000 | ValAcc 0.733
# Epoch  100 | Loss 0.4686 | TrainAcc 1.000 | ValAcc 0.733
# Epoch  110 | Loss 0.4667 | TrainAcc 1.000 | ValAcc 0.733
# Epoch  120 | Loss 0.4653 | TrainAcc 1.000 | ValAcc 0.733
# Epoch  130 | Loss 0.4641 | TrainAcc 1.000 | ValAcc 0.733
# Epoch  140 | Loss 0.4634 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  150 | Loss 0.4632 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  160 | Loss 0.4629 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  170 | Loss 0.4628 | TrainAcc 1.000 | ValAcc 0.667
# Epoch  180 | Loss 0.4626 | TrainAcc 1.000 | ValAcc 0.667
# Early stop triggered.
#
# Best ValAcc 0.733 | TestAcc 0.421
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.0179 | TrainAcc 0.522 | ValAcc 0.600
# Epoch   10 | Loss 0.9027 | TrainAcc 0.647 | ValAcc 0.600
# Epoch   20 | Loss 0.8814 | TrainAcc 0.647 | ValAcc 0.600
# Epoch   30 | Loss 0.8614 | TrainAcc 0.647 | ValAcc 0.600
# Epoch   40 | Loss 0.8419 | TrainAcc 0.647 | ValAcc 0.600
# Epoch   50 | Loss 0.8233 | TrainAcc 0.654 | ValAcc 0.600
# Epoch   60 | Loss 0.8056 | TrainAcc 0.654 | ValAcc 0.600
# Epoch   70 | Loss 0.7885 | TrainAcc 0.662 | ValAcc 0.533
# Epoch   80 | Loss 0.7719 | TrainAcc 0.669 | ValAcc 0.533
# Epoch   90 | Loss 0.7557 | TrainAcc 0.684 | ValAcc 0.533
# Epoch  100 | Loss 0.7400 | TrainAcc 0.699 | ValAcc 0.533
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.445
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.1359 | TrainAcc 0.390 | ValAcc 0.333
# Epoch   10 | Loss 0.8871 | TrainAcc 0.610 | ValAcc 0.133
# Epoch   20 | Loss 0.7179 | TrainAcc 0.809 | ValAcc 0.200
# Epoch   30 | Loss 0.6192 | TrainAcc 0.919 | ValAcc 0.333
# Epoch   40 | Loss 0.5591 | TrainAcc 0.978 | ValAcc 0.333
# Epoch   50 | Loss 0.5247 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   60 | Loss 0.5046 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   70 | Loss 0.4932 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   80 | Loss 0.4842 | TrainAcc 0.993 | ValAcc 0.333
# Epoch   90 | Loss 0.4772 | TrainAcc 0.993 | ValAcc 0.333
# Epoch  100 | Loss 0.4728 | TrainAcc 1.000 | ValAcc 0.333
# Early stop triggered.
#
# Best ValAcc 0.400 | TestAcc 0.392
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2523 | TrainAcc 0.301 | ValAcc 0.600
# Epoch   10 | Loss 1.1494 | TrainAcc 0.456 | ValAcc 0.400
# Epoch   20 | Loss 1.1152 | TrainAcc 0.471 | ValAcc 0.400
# Epoch   30 | Loss 1.0807 | TrainAcc 0.471 | ValAcc 0.400
# Epoch   40 | Loss 1.0411 | TrainAcc 0.478 | ValAcc 0.400
# Epoch   50 | Loss 0.9944 | TrainAcc 0.478 | ValAcc 0.400
# Epoch   60 | Loss 0.9452 | TrainAcc 0.515 | ValAcc 0.400
# Epoch   70 | Loss 0.9004 | TrainAcc 0.596 | ValAcc 0.467
# Epoch   80 | Loss 0.8614 | TrainAcc 0.743 | ValAcc 0.400
# Epoch   90 | Loss 0.8285 | TrainAcc 0.779 | ValAcc 0.400
# Epoch  100 | Loss 0.8017 | TrainAcc 0.816 | ValAcc 0.467
# Early stop triggered.
#
# Best ValAcc 0.600 | TestAcc 0.519
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.2026 | TrainAcc 0.353 | ValAcc 0.200
# ...
# Epoch   70 | Loss 1.0124 | TrainAcc 0.993 | ValAcc 0.235
# Epoch   80 | Loss 1.0049 | TrainAcc 1.000 | ValAcc 0.235
# Epoch   90 | Loss 0.9998 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  100 | Loss 0.9956 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  110 | Loss 0.9928 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  120 | Loss 0.9909 | TrainAcc 1.000 | ValAcc 0.235
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.254
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8230 | TrainAcc 0.152 | ValAcc 0.118
# Epoch   10 | Loss 1.6988 | TrainAcc 0.278 | ValAcc 0.176
# Epoch   20 | Loss 1.6623 | TrainAcc 0.338 | ValAcc 0.176
# Epoch   30 | Loss 1.6281 | TrainAcc 0.364 | ValAcc 0.176
# Epoch   40 | Loss 1.5949 | TrainAcc 0.417 | ValAcc 0.176
# Epoch   50 | Loss 1.5619 | TrainAcc 0.444 | ValAcc 0.176
# Epoch   60 | Loss 1.5286 | TrainAcc 0.457 | ValAcc 0.176
# Epoch   70 | Loss 1.4949 | TrainAcc 0.457 | ValAcc 0.176
# Epoch   80 | Loss 1.4610 | TrainAcc 0.563 | ValAcc 0.176
# Epoch   90 | Loss 1.4279 | TrainAcc 0.570 | ValAcc 0.176
# Epoch  100 | Loss 1.3981 | TrainAcc 0.596 | ValAcc 0.176
# Early stop triggered.
#
# Best ValAcc 0.176 | TestAcc 0.281
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8773 | TrainAcc 0.185 | ValAcc 0.118
# Epoch   10 | Loss 1.5462 | TrainAcc 0.477 | ValAcc 0.235
# Epoch   20 | Loss 1.3365 | TrainAcc 0.715 | ValAcc 0.235
# Epoch   30 | Loss 1.2063 | TrainAcc 0.887 | ValAcc 0.118
# Epoch   40 | Loss 1.1261 | TrainAcc 0.954 | ValAcc 0.118
# Epoch   50 | Loss 1.0799 | TrainAcc 0.980 | ValAcc 0.176
# Epoch   60 | Loss 1.0513 | TrainAcc 0.980 | ValAcc 0.176
# Epoch   70 | Loss 1.0333 | TrainAcc 0.987 | ValAcc 0.118
# Epoch   80 | Loss 1.0216 | TrainAcc 0.987 | ValAcc 0.118
# Epoch   90 | Loss 1.0133 | TrainAcc 0.987 | ValAcc 0.118
# Epoch  100 | Loss 1.0071 | TrainAcc 0.993 | ValAcc 0.118
# Epoch  110 | Loss 1.0023 | TrainAcc 1.000 | ValAcc 0.118
# Early stop triggered.
#
# Best ValAcc 0.294 | TestAcc 0.221
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.7757 | TrainAcc 0.179 | ValAcc 0.059
# Epoch   10 | Loss 1.6583 | TrainAcc 0.325 | ValAcc 0.118
# Epoch   20 | Loss 1.6161 | TrainAcc 0.325 | ValAcc 0.118
# Epoch   30 | Loss 1.5770 | TrainAcc 0.377 | ValAcc 0.118
# Epoch   40 | Loss 1.5411 | TrainAcc 0.576 | ValAcc 0.059
# Epoch   50 | Loss 1.5088 | TrainAcc 0.583 | ValAcc 0.059
# Epoch   60 | Loss 1.4805 | TrainAcc 0.596 | ValAcc 0.059
# Epoch   70 | Loss 1.4556 | TrainAcc 0.616 | ValAcc 0.059
# Epoch   80 | Loss 1.4326 | TrainAcc 0.623 | ValAcc 0.059
# Epoch   90 | Loss 1.4102 | TrainAcc 0.629 | ValAcc 0.059
# Epoch  100 | Loss 1.3880 | TrainAcc 0.642 | ValAcc 0.118
# Early stop triggered.
#
# Best ValAcc 0.118 | TestAcc 0.252
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8713 | TrainAcc 0.132 | ValAcc 0.235
# Epoch   10 | Loss 1.5206 | TrainAcc 0.470 | ValAcc 0.235
# Epoch   20 | Loss 1.3036 | TrainAcc 0.709 | ValAcc 0.412
# Epoch   30 | Loss 1.1850 | TrainAcc 0.854 | ValAcc 0.412
# Epoch   40 | Loss 1.1172 | TrainAcc 0.921 | ValAcc 0.353
# Epoch   50 | Loss 1.0752 | TrainAcc 0.954 | ValAcc 0.176
# Epoch   60 | Loss 1.0493 | TrainAcc 0.974 | ValAcc 0.235
# Epoch   70 | Loss 1.0318 | TrainAcc 0.993 | ValAcc 0.235
# Epoch   80 | Loss 1.0193 | TrainAcc 1.000 | ValAcc 0.235
# Epoch   90 | Loss 1.0106 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  100 | Loss 1.0046 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  110 | Loss 0.9997 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  120 | Loss 0.9963 | TrainAcc 1.000 | ValAcc 0.235
# Early stop triggered.
#
# Best ValAcc 0.471 | TestAcc 0.252
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.7352 | TrainAcc 0.172 | ValAcc 0.118
# Epoch   10 | Loss 1.6275 | TrainAcc 0.285 | ValAcc 0.235
# Epoch   20 | Loss 1.5832 | TrainAcc 0.371 | ValAcc 0.235
# Epoch   30 | Loss 1.5415 | TrainAcc 0.391 | ValAcc 0.235
# Epoch   40 | Loss 1.5024 | TrainAcc 0.411 | ValAcc 0.235
# Epoch   50 | Loss 1.4653 | TrainAcc 0.411 | ValAcc 0.294
# Epoch   60 | Loss 1.4302 | TrainAcc 0.517 | ValAcc 0.353
# Epoch   70 | Loss 1.3975 | TrainAcc 0.550 | ValAcc 0.353
# Epoch   80 | Loss 1.3672 | TrainAcc 0.649 | ValAcc 0.353
# Epoch   90 | Loss 1.3393 | TrainAcc 0.682 | ValAcc 0.353
# Epoch  100 | Loss 1.3132 | TrainAcc 0.748 | ValAcc 0.353
# Epoch  110 | Loss 1.2891 | TrainAcc 0.775 | ValAcc 0.353
# Epoch  120 | Loss 1.2665 | TrainAcc 0.781 | ValAcc 0.353
# Epoch  130 | Loss 1.2456 | TrainAcc 0.781 | ValAcc 0.353
# Epoch  140 | Loss 1.2262 | TrainAcc 0.781 | ValAcc 0.353
# Epoch  150 | Loss 1.2088 | TrainAcc 0.781 | ValAcc 0.353
# Epoch  160 | Loss 1.1934 | TrainAcc 0.821 | ValAcc 0.353
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.353
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8643 | TrainAcc 0.172 | ValAcc 0.000
# Epoch   10 | Loss 1.5444 | TrainAcc 0.444 | ValAcc 0.118
# Epoch   20 | Loss 1.3211 | TrainAcc 0.728 | ValAcc 0.235
# Epoch   30 | Loss 1.1825 | TrainAcc 0.874 | ValAcc 0.176
# Epoch   40 | Loss 1.1001 | TrainAcc 0.954 | ValAcc 0.294
# Epoch   50 | Loss 1.0527 | TrainAcc 0.987 | ValAcc 0.235
# Epoch   60 | Loss 1.0241 | TrainAcc 0.993 | ValAcc 0.235
# Epoch   70 | Loss 1.0052 | TrainAcc 1.000 | ValAcc 0.235
# Epoch   80 | Loss 0.9964 | TrainAcc 1.000 | ValAcc 0.294
# Epoch   90 | Loss 0.9923 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  100 | Loss 0.9900 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  110 | Loss 0.9887 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  120 | Loss 0.9878 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  130 | Loss 0.9872 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  140 | Loss 0.9867 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  150 | Loss 0.9863 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  160 | Loss 0.9859 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  170 | Loss 0.9857 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  180 | Loss 0.9855 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  190 | Loss 0.9853 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  200 | Loss 0.9851 | TrainAcc 1.000 | ValAcc 0.353
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.237
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8203 | TrainAcc 0.179 | ValAcc 0.176
# Epoch   10 | Loss 1.6654 | TrainAcc 0.417 | ValAcc 0.235
# Epoch   20 | Loss 1.6250 | TrainAcc 0.430 | ValAcc 0.235
# Epoch   30 | Loss 1.5857 | TrainAcc 0.437 | ValAcc 0.235
# Epoch   40 | Loss 1.5474 | TrainAcc 0.450 | ValAcc 0.294
# Epoch   50 | Loss 1.5088 | TrainAcc 0.477 | ValAcc 0.294
# Epoch   60 | Loss 1.4698 | TrainAcc 0.576 | ValAcc 0.353
# Epoch   70 | Loss 1.4317 | TrainAcc 0.603 | ValAcc 0.353
# Epoch   80 | Loss 1.3955 | TrainAcc 0.636 | ValAcc 0.353
# Epoch   90 | Loss 1.3605 | TrainAcc 0.669 | ValAcc 0.353
# Epoch  100 | Loss 1.3276 | TrainAcc 0.702 | ValAcc 0.412
# Epoch  110 | Loss 1.2980 | TrainAcc 0.748 | ValAcc 0.412
# Epoch  120 | Loss 1.2726 | TrainAcc 0.762 | ValAcc 0.412
# Epoch  130 | Loss 1.2504 | TrainAcc 0.821 | ValAcc 0.412
# Epoch  140 | Loss 1.2306 | TrainAcc 0.848 | ValAcc 0.412
# Epoch  150 | Loss 1.2143 | TrainAcc 0.861 | ValAcc 0.412
# Epoch  160 | Loss 1.1998 | TrainAcc 0.861 | ValAcc 0.412
# Epoch  170 | Loss 1.1876 | TrainAcc 0.861 | ValAcc 0.353
# Epoch  180 | Loss 1.1782 | TrainAcc 0.861 | ValAcc 0.353
# Epoch  190 | Loss 1.1709 | TrainAcc 0.861 | ValAcc 0.353
# Early stop triggered.
#
# Best ValAcc 0.412 | TestAcc 0.305
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8654 | TrainAcc 0.192 | ValAcc 0.176
# Epoch   10 | Loss 1.5530 | TrainAcc 0.444 | ValAcc 0.412
# Epoch   20 | Loss 1.3158 | TrainAcc 0.735 | ValAcc 0.412
# Epoch   30 | Loss 1.1746 | TrainAcc 0.901 | ValAcc 0.235
# Epoch   40 | Loss 1.1000 | TrainAcc 0.954 | ValAcc 0.235
# Epoch   50 | Loss 1.0588 | TrainAcc 0.980 | ValAcc 0.235
# Epoch   60 | Loss 1.0358 | TrainAcc 0.987 | ValAcc 0.235
# Epoch   70 | Loss 1.0215 | TrainAcc 0.987 | ValAcc 0.235
# Epoch   80 | Loss 1.0119 | TrainAcc 1.000 | ValAcc 0.235
# Epoch   90 | Loss 1.0048 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  100 | Loss 1.0011 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  110 | Loss 0.9982 | TrainAcc 1.000 | ValAcc 0.353
# Early stop triggered.
#
# Best ValAcc 0.412 | TestAcc 0.256
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8622 | TrainAcc 0.079 | ValAcc 0.118
# Epoch   10 | Loss 1.7022 | TrainAcc 0.338 | ValAcc 0.353
# Epoch   20 | Loss 1.6612 | TrainAcc 0.338 | ValAcc 0.353
# Epoch   30 | Loss 1.6233 | TrainAcc 0.344 | ValAcc 0.353
# Epoch   40 | Loss 1.5870 | TrainAcc 0.358 | ValAcc 0.353
# Epoch   50 | Loss 1.5513 | TrainAcc 0.377 | ValAcc 0.353
# Epoch   60 | Loss 1.5153 | TrainAcc 0.411 | ValAcc 0.353
# Epoch   70 | Loss 1.4797 | TrainAcc 0.450 | ValAcc 0.353
# Epoch   80 | Loss 1.4447 | TrainAcc 0.543 | ValAcc 0.353
# Epoch   90 | Loss 1.4116 | TrainAcc 0.649 | ValAcc 0.353
# Epoch  100 | Loss 1.3809 | TrainAcc 0.702 | ValAcc 0.353
# Early stop triggered.
#
# Best ValAcc 0.412 | TestAcc 0.328
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8479 | TrainAcc 0.152 | ValAcc 0.059
# Epoch   10 | Loss 1.5524 | TrainAcc 0.417 | ValAcc 0.118
# Epoch   20 | Loss 1.3352 | TrainAcc 0.742 | ValAcc 0.294
# Epoch   30 | Loss 1.2022 | TrainAcc 0.874 | ValAcc 0.353
# Epoch   40 | Loss 1.1183 | TrainAcc 0.927 | ValAcc 0.471
# Epoch   50 | Loss 1.0677 | TrainAcc 0.967 | ValAcc 0.471
# Epoch   60 | Loss 1.0395 | TrainAcc 0.987 | ValAcc 0.412
# Epoch   70 | Loss 1.0232 | TrainAcc 0.987 | ValAcc 0.412
# Epoch   80 | Loss 1.0133 | TrainAcc 0.993 | ValAcc 0.412
# Epoch   90 | Loss 1.0063 | TrainAcc 0.993 | ValAcc 0.412
# Epoch  100 | Loss 1.0022 | TrainAcc 0.993 | ValAcc 0.412
# Epoch  110 | Loss 0.9980 | TrainAcc 1.000 | ValAcc 0.412
# Epoch  120 | Loss 0.9939 | TrainAcc 1.000 | ValAcc 0.412
# Epoch  130 | Loss 0.9917 | TrainAcc 1.000 | ValAcc 0.412
# Epoch  140 | Loss 0.9900 | TrainAcc 1.000 | ValAcc 0.412
# Early stop triggered.
#
# Best ValAcc 0.471 | TestAcc 0.265
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.7885 | TrainAcc 0.199 | ValAcc 0.118
# Epoch   10 | Loss 1.6939 | TrainAcc 0.298 | ValAcc 0.235
# Epoch   20 | Loss 1.6524 | TrainAcc 0.298 | ValAcc 0.235
# Epoch   30 | Loss 1.6143 | TrainAcc 0.318 | ValAcc 0.235
# Epoch   40 | Loss 1.5800 | TrainAcc 0.358 | ValAcc 0.235
# Epoch   50 | Loss 1.5490 | TrainAcc 0.424 | ValAcc 0.235
# Epoch   60 | Loss 1.5208 | TrainAcc 0.510 | ValAcc 0.294
# Epoch   70 | Loss 1.4938 | TrainAcc 0.517 | ValAcc 0.294
# Epoch   80 | Loss 1.4676 | TrainAcc 0.530 | ValAcc 0.294
# Epoch   90 | Loss 1.4421 | TrainAcc 0.596 | ValAcc 0.294
# Epoch  100 | Loss 1.4163 | TrainAcc 0.603 | ValAcc 0.294
# Epoch  110 | Loss 1.3902 | TrainAcc 0.603 | ValAcc 0.294
# Epoch  120 | Loss 1.3645 | TrainAcc 0.609 | ValAcc 0.294
# Epoch  130 | Loss 1.3395 | TrainAcc 0.656 | ValAcc 0.294
# Epoch  140 | Loss 1.3155 | TrainAcc 0.709 | ValAcc 0.294
# Epoch  150 | Loss 1.2937 | TrainAcc 0.722 | ValAcc 0.294
# Early stop triggered.
#
# Best ValAcc 0.294 | TestAcc 0.268
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8611 | TrainAcc 0.152 | ValAcc 0.235
# Epoch   10 | Loss 1.5139 | TrainAcc 0.497 | ValAcc 0.353
# Epoch   20 | Loss 1.3013 | TrainAcc 0.735 | ValAcc 0.235
# Epoch   30 | Loss 1.1773 | TrainAcc 0.881 | ValAcc 0.118
# Epoch   40 | Loss 1.0992 | TrainAcc 0.947 | ValAcc 0.235
# Epoch   50 | Loss 1.0535 | TrainAcc 0.960 | ValAcc 0.235
# Epoch   60 | Loss 1.0266 | TrainAcc 0.987 | ValAcc 0.176
# Epoch   70 | Loss 1.0114 | TrainAcc 1.000 | ValAcc 0.176
# Epoch   80 | Loss 1.0024 | TrainAcc 1.000 | ValAcc 0.176
# Epoch   90 | Loss 0.9974 | TrainAcc 1.000 | ValAcc 0.176
# Epoch  100 | Loss 0.9944 | TrainAcc 1.000 | ValAcc 0.176
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.239
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.6775 | TrainAcc 0.305 | ValAcc 0.176
# Epoch   10 | Loss 1.5602 | TrainAcc 0.483 | ValAcc 0.294
# Epoch   20 | Loss 1.5219 | TrainAcc 0.510 | ValAcc 0.235
# Epoch   30 | Loss 1.4870 | TrainAcc 0.583 | ValAcc 0.294
# Epoch   40 | Loss 1.4558 | TrainAcc 0.609 | ValAcc 0.294
# Epoch   50 | Loss 1.4280 | TrainAcc 0.636 | ValAcc 0.294
# Epoch   60 | Loss 1.4030 | TrainAcc 0.642 | ValAcc 0.353
# Epoch   70 | Loss 1.3803 | TrainAcc 0.662 | ValAcc 0.294
# Epoch   80 | Loss 1.3595 | TrainAcc 0.662 | ValAcc 0.353
# Epoch   90 | Loss 1.3401 | TrainAcc 0.669 | ValAcc 0.294
# Epoch  100 | Loss 1.3218 | TrainAcc 0.623 | ValAcc 0.294
# Epoch  110 | Loss 1.3049 | TrainAcc 0.629 | ValAcc 0.235
# Epoch  120 | Loss 1.2892 | TrainAcc 0.675 | ValAcc 0.118
# Epoch  130 | Loss 1.2750 | TrainAcc 0.755 | ValAcc 0.118
# Epoch  140 | Loss 1.2622 | TrainAcc 0.768 | ValAcc 0.118
# Epoch  150 | Loss 1.2503 | TrainAcc 0.788 | ValAcc 0.118
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.271
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8785 | TrainAcc 0.126 | ValAcc 0.235
# Epoch   10 | Loss 1.5724 | TrainAcc 0.391 | ValAcc 0.353
# Epoch   20 | Loss 1.3566 | TrainAcc 0.636 | ValAcc 0.353
# Epoch   30 | Loss 1.2189 | TrainAcc 0.861 | ValAcc 0.294
# Epoch   40 | Loss 1.1354 | TrainAcc 0.934 | ValAcc 0.235
# Epoch   50 | Loss 1.0835 | TrainAcc 0.967 | ValAcc 0.294
# Epoch   60 | Loss 1.0510 | TrainAcc 0.974 | ValAcc 0.294
# Epoch   70 | Loss 1.0319 | TrainAcc 0.993 | ValAcc 0.235
# Epoch   80 | Loss 1.0190 | TrainAcc 1.000 | ValAcc 0.176
# Epoch   90 | Loss 1.0097 | TrainAcc 1.000 | ValAcc 0.176
# Epoch  100 | Loss 1.0034 | TrainAcc 1.000 | ValAcc 0.176
# Epoch  110 | Loss 0.9987 | TrainAcc 1.000 | ValAcc 0.176
# Early stop triggered.
#
# Best ValAcc 0.412 | TestAcc 0.240
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8374 | TrainAcc 0.139 | ValAcc 0.118
# Epoch   10 | Loss 1.7062 | TrainAcc 0.258 | ValAcc 0.353
# Epoch   20 | Loss 1.6597 | TrainAcc 0.272 | ValAcc 0.294
# Epoch   30 | Loss 1.6149 | TrainAcc 0.278 | ValAcc 0.294
# Epoch   40 | Loss 1.5722 | TrainAcc 0.298 | ValAcc 0.294
# Epoch   50 | Loss 1.5317 | TrainAcc 0.344 | ValAcc 0.294
# Epoch   60 | Loss 1.4929 | TrainAcc 0.477 | ValAcc 0.294
# Epoch   70 | Loss 1.4560 | TrainAcc 0.596 | ValAcc 0.294
# Epoch   80 | Loss 1.4205 | TrainAcc 0.675 | ValAcc 0.294
# Epoch   90 | Loss 1.3863 | TrainAcc 0.709 | ValAcc 0.059
# Epoch  100 | Loss 1.3536 | TrainAcc 0.715 | ValAcc 0.059
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.249
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.8820 | TrainAcc 0.139 | ValAcc 0.059
# Epoch   10 | Loss 1.5344 | TrainAcc 0.470 | ValAcc 0.059
# Epoch   20 | Loss 1.3249 | TrainAcc 0.728 | ValAcc 0.235
# Epoch   30 | Loss 1.2053 | TrainAcc 0.841 | ValAcc 0.176
# Epoch   40 | Loss 1.1326 | TrainAcc 0.907 | ValAcc 0.176
# Epoch   50 | Loss 1.0820 | TrainAcc 0.967 | ValAcc 0.294
# Epoch   60 | Loss 1.0445 | TrainAcc 0.993 | ValAcc 0.294
# Epoch   70 | Loss 1.0238 | TrainAcc 0.993 | ValAcc 0.294
# Epoch   80 | Loss 1.0103 | TrainAcc 1.000 | ValAcc 0.294
# Epoch   90 | Loss 1.0021 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  100 | Loss 0.9970 | TrainAcc 1.000 | ValAcc 0.353
# Epoch  110 | Loss 0.9938 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  120 | Loss 0.9912 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  130 | Loss 0.9892 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  140 | Loss 0.9876 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  150 | Loss 0.9865 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  160 | Loss 0.9855 | TrainAcc 1.000 | ValAcc 0.294
# Epoch  170 | Loss 0.9848 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  180 | Loss 0.9843 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  190 | Loss 0.9839 | TrainAcc 1.000 | ValAcc 0.235
# Epoch  200 | Loss 0.9837 | TrainAcc 1.000 | ValAcc 0.235
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.233
# --- Initializing GCN model with 3 layers ---
# Epoch    1 | Loss 1.7190 | TrainAcc 0.166 | ValAcc 0.118
# Epoch   10 | Loss 1.5490 | TrainAcc 0.523 | ValAcc 0.294
# Epoch   20 | Loss 1.5060 | TrainAcc 0.583 | ValAcc 0.235
# Epoch   30 | Loss 1.4650 | TrainAcc 0.603 | ValAcc 0.235
# Epoch   40 | Loss 1.4261 | TrainAcc 0.682 | ValAcc 0.176
# Epoch   50 | Loss 1.3890 | TrainAcc 0.715 | ValAcc 0.235
# Epoch   60 | Loss 1.3554 | TrainAcc 0.788 | ValAcc 0.235
# Epoch   70 | Loss 1.3254 | TrainAcc 0.861 | ValAcc 0.235
# Epoch   80 | Loss 1.2988 | TrainAcc 0.868 | ValAcc 0.235
# Epoch   90 | Loss 1.2754 | TrainAcc 0.881 | ValAcc 0.294
# Epoch  100 | Loss 1.2552 | TrainAcc 0.881 | ValAcc 0.294
# Early stop triggered.
#
# Best ValAcc 0.353 | TestAcc 0.334
# GEE = 0.2420±0.0019,         GNN = 0.2454±0.0027,            GG = 0.2927±0.0034,                GG2 = 0.3057±0.0030

# %%
# torch.manual_seed(901)
# random.seed(901)
# np.random.seed(901)
# num_folds = 5
# print(data_list)

# for dataname in data_list:
#     print(dataname)
#     data = load_real_data(dataname)
#     edge_list = [(int(data.edge_index[0, i]), int(data.edge_index[1, i]), 1) for i in range(data.edge_index.shape[1])]
#     initializer = nn.init.xavier_uniform_
#     z = initializer(torch.empty(data.num_nodes, data.k))
#     data.x = z
#     classes, counts = np.unique(data.y, return_counts=True)
#     print(classes, counts)  
#     # all_splits = stratified_split(data.y, train_ratio=0.9/num_folds, val_ratio=0.1/num_folds, test_ratio=1/num_folds, n_repeats=2)
